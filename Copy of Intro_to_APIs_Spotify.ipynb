# %%
# https://spotipy.readthedocs.io/en/2.19.0/

# Install spotipy
# As google colab starts each session like a new computer, we must install this each time.
# If you are working on your local machine, you only need to install it once.
# !pip install spotipy --upgrade
# !pip install urllib3 --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.21.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 35.8 MB/s
# Collecting requests>=2.25.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Collecting redis>=3.5.3
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 60.9 MB/s
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.1.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (21.3)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.13.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.3->spotipy) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Installing collected packages: urllib3, deprecated, requests, redis, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed deprecated-1.2.13 redis-4.3.4 requests-2.28.1 spotipy-2.21.0 urllib3-1.26.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (1.26.12)

# %%
import pandas as pd

# %% [markdown]
# ## Requests
#
# The requests library is the de facto standard for making HTTP requests in Python. It abstracts the complexities of making requests behind a beautiful, simple API so that you can focus on interacting with services and consuming data in your application.
#
# https://requests.readthedocs.io/en/latest/
#
# When we make a request, we get a requests.Response object in return. The requests.Response object contains the server's response to the HTTP request. Part of this response is a number - which represents whether we received the information we wanted or not. If you get a number that you don't understand, these cats will help you: https://http.cat/
#
# More often than not you'll receive:
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

wbscs = requests.get("https://www.wbscodingschool.com/")
print("WBS CS: ", wbscs.status_code)
# Out:
# Google: 200
# NBA: 401
# WBS CS:  403

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Intro - making a request and viewing the JSON
#
# https://docs.python.org/3/library/json.html
#
# Since its inception, JSON has quickly become the de facto standard for information exchange. JSON supports primitive types, like strings and numbers, as well as nested lists and objects. It looks like nested python dictionaries:
#
# `{"firstname": "Harry",
# "lastname": "Noah",
# "city": "Berlin",
# "dogs": [{"name": "rover", "breed": "labrador"}, {"name": "pip", "breed": "spaniel"}],
# "cars": "none"}`

# %%
import json

# %%
# Make the request.
response = requests.get("https://jsonplaceholder.typicode.com/users")

# %%
# Check the HTTP code.
response
# Out:
# <Response [200]>

# %%
# Example of what a JSON looks like.

# View API response as a JSON.
response.json()
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
#  {'id': 3,
#   'name': 'Clementine Bauch',
#   'username': 'Samantha',
#   'email': 'Nathan@yesenia.net',
#   'address': {'street': 'Douglas Extension',
#    'suite': 'Suite 847',
#    'city': 'McKenziehaven',
#    'zipcode': '59590-4157',
#    'geo': {'lat': '-68.6102', 'lng': '-47.0653'}},
#   'phone': '1-463-123-4447',
#   'website': 'ramiro.info',
#   'company': {'name': 'Romaguera-Jacobson',
#    'catchPhrase': 'Face to face bifurcated interface',
#    'bs': 'e-enable strategic applications'}},
#  {'id': 4,
#   'name': 'Patricia Lebsack',
#   'username': 'Karianne',
#   'email': 'Julianne.OConner@kory.org',
#   'address': {'street': 'Hoeger Mall',
#    'suite': 'Apt. 692',
#    'city': 'South Elvis',
#    'zipcode': '53919-4257',
#    'geo': {'lat': '29.4572', 'lng': '-164.2990'}},
#   'phone': '493-170-9623 x156',
#   'website': 'kale.biz',
#   'company': {'name': 'Robel-Corkery',
#    'catchPhrase': 'Multi-tiered zero tolerance productivity',
#    'bs': 'transition cutting-edge web services'}},
#  {'id': 5,
#   'name': 'Chelsey Dietrich',
#   'username': 'Kamren',
#   'email': 'Lucio_Hettinger@annie.ca',
#   'address': {'street': 'Skiles Walks',
#    'suite': 'Suite 351',
#    'city': 'Roscoeview',
#    'zipcode': '33263',
#    'geo': {'lat': '-31.8129', 'lng': '62.5342'}},
#   'phone': '(254)954-1289',
#   'website': 'demarco.info',
#   'company': {'name': 'Keebler LLC',
#    'catchPhrase': 'User-centric fault-tolerant solution',
#    'bs': 'revolutionize end-to-end systems'}},
#  {'id': 6,
#   'name': 'Mrs. Dennis Schulist',
#   'username': 'Leopoldo_Corkery',
#   'email': 'Karley_Dach@jasper.info',
#   'address': {'street': 'Norberto Crossing',
#    'suite': 'Apt. 950',
#    'city': 'South Christy',
#    'zipcode': '23505-1337',
#    'geo': {'lat': '-71.4197', 'lng': '71.7478'}},
#   'phone': '1-477-935-8478 x6430',
#   'website': 'ola.org',
#   'company': {'name': 'Considine-Lockman',
#    'catchPhrase': 'Synchronised bottom-line interface',
#    'bs': 'e-enable innovative applications'}},
#  {'id': 7,
#   'name': 'Kurtis Weissnat',
#   'username': 'Elwyn.Skiles',
#   'email': 'Telly.Hoeger@billy.biz',
#   'address': {'street': 'Rex Trail',
#    'suite': 'Suite 280',
#    'city': 'Howemouth',
#    'zipcode': '58804-1099',
#    'geo': {'lat': '24.8918', 'lng': '21.8984'}},
#   'phone': '210.067.6132',
#   'website': 'elvis.io',
#   'company': {'name': 'Johns Group',
#    'catchPhrase': 'Configurable multimedia task-force',
#    'bs': 'generate enterprise e-tailers'}},
#  {'id': 8,
#   'name': 'Nicholas Runolfsdottir V',
#   'username': 'Maxime_Nienow',
#   'email': 'Sherwood@rosamond.me',
#   'address': {'street': 'Ellsworth Summit',
#    'suite': 'Suite 729',
#    'city': 'Aliyaview',
#    'zipcode': '45169',
#    'geo': {'lat': '-14.3990', 'lng': '-120.7677'}},
#   'phone': '586.493.6943 x140',
#   'website': 'jacynthe.com',
#   'company': {'name': 'Abernathy Group',
#    'catchPhrase': 'Implemented secondary concept',
#    'bs': 'e-enable extensible e-tailers'}},
#  {'id': 9,
#   'name': 'Glenna Reichert',
#   'username': 'Delphine',
#   'email': 'Chaim_McDermott@dana.io',
#   'address': {'street': 'Dayna Park',
#    'suite': 'Suite 449',
#    'city': 'Bartholomebury',
#    'zipcode': '76495-3109',
#    'geo': {'lat': '24.6463', 'lng': '-168.8889'}},
#   'phone': '(775)976-6794 x41206',
#   'website': 'conrad.com',
#   'company': {'name': 'Yost and Sons',
#    'catchPhrase': 'Switchable contextually-based project',
#    'bs': 'aggregate real-time technologies'}},
#  {'id': 10,
#   'name': 'Clementina DuBuque',
#   'username': 'Moriah.Stanton',
#   'email': 'Rey.Padberg@karina.biz',
#   'address': {'street': 'Kattie Turnpike',
#    'suite': 'Suite 198',
#    'city': 'Lebsackbury',
#    'zipcode': '31428-2261',
#    'geo': {'lat': '-38.2386', 'lng': '57.2232'}},
#   'phone': '024-648-3804',
#   'website': 'ambrose.net',
#   'company': {'name': 'Hoeger LLC',
#    'catchPhrase': 'Centralized empowering task-force',
#    'bs': 'target end-to-end models'}}]

# %% [markdown]
# ### GitHub API - Accessing the data in the JSON
#
# Now that we know
# - what an API is,
# - how to request information from one (requests),
# - how the information will be delivered to us (JSON):
#
# Let's look how we can use this information. We will first look at how we can access particular values within the JSON. Then we will look at a couple of methods to make a dataframe from the JSON.
#
# Github has many APIs. Here we'll look at two of them.

# %%
# Very basic API (a string returned).

# GitHub's Zen API produces a new inspirational phrase every 30 seconds.
# Run this cell again in 30 seconds to see a different output.

resp = requests.get("https://api.github.com/zen")
resp.text
# Out:
# 'Keep it logically awesome.'

# %%
# More complex API (a large json returned).

# Github's Event API shows the events that power the various activity streams on the site.
# In other words, what's happening on Github, who's updating what?

response = requests.get('https://api.github.com/events')
github_response = response.json()
github_response
# Out:
# [{'id': '24953882621',
#   'type': 'CreateEvent',
#   'actor': {'id': 37222518,
#    'login': 'Prash28',
#    'display_login': 'Prash28',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Prash28',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37222518?'},
#   'repo': {'id': 560351309,
#    'name': 'Prash28/C-',
#    'url': 'https://api.github.com/repos/Prash28/C-'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882586',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 7776826,
#    'login': 'giadefa',
#    'display_login': 'giadefa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/giadefa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7776826?'},
#   'repo': {'id': 356331061,
#    'name': 'torchmd/torchmd-net',
#    'url': 'https://api.github.com/repos/torchmd/torchmd-net'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145',
#     'repository_url': 'https://api.github.com/repos/torchmd/torchmd-net',
#     'labels_url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145/comments',
#     'events_url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145/events',
#     'html_url': 'https://github.com/torchmd/torchmd-net/issues/145',
#     'id': 1430712179,
#     'node_id': 'I_kwDOFT0uNc5VRu9z',
#     'number': 145,
#     'title': 'An error occurred in setting up the environment',
#     'user': {'login': 'mukui123',
#      'id': 90401610,
#      'node_id': 'MDQ6VXNlcjkwNDAxNjEw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/90401610?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mukui123',
#      'html_url': 'https://github.com/mukui123',
#      'followers_url': 'https://api.github.com/users/mukui123/followers',
#      'following_url': 'https://api.github.com/users/mukui123/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mukui123/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mukui123/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mukui123/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mukui123/orgs',
#      'repos_url': 'https://api.github.com/users/mukui123/repos',
#      'events_url': 'https://api.github.com/users/mukui123/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mukui123/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2022-11-01T01:30:42Z',
#     'updated_at': '2022-11-01T09:57:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'I set up the environment according to the installation manual. Every time I create a virtual environment, cudatoolkit11.7.0 will be downloaded automatically. However, my Linux cuda version is 11.6, running torchmd-train will report such an error, can you solve it? Thank you very much!\r\n![image](https://user-images.githubusercontent.com/90401610/199138955-10601894-6a01-4726-8064-a5d70148822a.png)\r\n![image](https://user-images.githubusercontent.com/90401610/199139051-72676bc8-ab33-4373-b456-0e6b95bc9246.png)\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/comments/1298291762',
#     'html_url': 'https://github.com/torchmd/torchmd-net/issues/145#issuecomment-1298291762',
#     'issue_url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/145',
#     'id': 1298291762,
#     'node_id': 'IC_kwDOFT0uNc5NYlwy',
#     'user': {'login': 'giadefa',
#      'id': 7776826,
#      'node_id': 'MDQ6VXNlcjc3NzY4MjY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7776826?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/giadefa',
#      'html_url': 'https://github.com/giadefa',
#      'followers_url': 'https://api.github.com/users/giadefa/followers',
#      'following_url': 'https://api.github.com/users/giadefa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/giadefa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/giadefa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/giadefa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/giadefa/orgs',
#      'repos_url': 'https://api.github.com/users/giadefa/repos',
#      'events_url': 'https://api.github.com/users/giadefa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/giadefa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-11-01T09:57:54Z',
#     'updated_at': '2022-11-01T09:57:54Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Does your Nvidia driver support Cuda11.7? Is it new enough? try to update\nthe driver\n\nOn Tue, Nov 1, 2022 at 2:30 AM mukui123 ***@***.***> wrote:\n\n> I set up the environment according to the installation manual. Every time\n> I create a virtual environment, cudatoolkit11.7.0 will be downloaded\n> automatically. However, my Linux cuda version is 11.6, running\n> torchmd-train will report such an error, can you solve it? Thank you very\n> much!\n> [image: image]\n> <https://user-images.githubusercontent.com/90401610/199138955-10601894-6a01-4726-8064-a5d70148822a.png>\n> [image: image]\n> <https://user-images.githubusercontent.com/90401610/199139051-72676bc8-ab33-4373-b456-0e6b95bc9246.png>\n>\n> —\n> Reply to this email directly, view it on GitHub\n> <https://github.com/torchmd/torchmd-net/issues/145>, or unsubscribe\n> <https://github.com/notifications/unsubscribe-auth/AB3KUOV6ONJVIUTLDSSKCVLWGBXE3ANCNFSM6AAAAAARTTYLCI>\n> .\n> You are receiving this because you are subscribed to this thread.Message\n> ID: ***@***.***>\n>\n',
#     'reactions': {'url': 'https://api.github.com/repos/torchmd/torchmd-net/issues/comments/1298291762/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 71184047,
#    'login': 'torchmd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/torchmd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71184047?'}},
#  {'id': '24953882537',
#   'type': 'PushEvent',
#   'actor': {'id': 116969040,
#    'login': 'Zqxg',
#    'display_login': 'Zqxg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zqxg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116969040?'},
#   'repo': {'id': 559293948,
#    'name': 'Zqxg/Tasks',
#    'url': 'https://api.github.com/repos/Zqxg/Tasks'},
#   'payload': {'push_id': 11514974977,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6644ac70d71217f33f87b424981d2be7bbf41cd6',
#    'before': 'ec137a6c48c556e948e8d272f47127f8c7650543',
#    'commits': [{'sha': '6644ac70d71217f33f87b424981d2be7bbf41cd6',
#      'author': {'email': '116969040+Zqxg@users.noreply.github.com',
#       'name': '蒸汽小锅'},
#      'message': 'git的工作原理图',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zqxg/Tasks/commits/6644ac70d71217f33f87b424981d2be7bbf41cd6'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882584',
#   'type': 'CreateEvent',
#   'actor': {'id': 95440233,
#    'login': 'rialele',
#    'display_login': 'rialele',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rialele',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95440233?'},
#   'repo': {'id': 560352820,
#    'name': 'rialele/blood-bank-managment-system',
#    'url': 'https://api.github.com/repos/rialele/blood-bank-managment-system'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882560',
#   'type': 'PushEvent',
#   'actor': {'id': 98070882,
#    'login': 'seryozha1989',
#    'display_login': 'seryozha1989',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seryozha1989',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98070882?'},
#   'repo': {'id': 458034268,
#    'name': 'seryozha1989/-5999455317753235474',
#    'url': 'https://api.github.com/repos/seryozha1989/-5999455317753235474'},
#   'payload': {'push_id': 11514975017,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2002063b8ecb80ccd5d9b448b3c5d411c39d0b3e',
#    'before': 'b8c7e7a339586d5403b829d246dac74052521d12',
#    'commits': [{'sha': '2002063b8ecb80ccd5d9b448b3c5d411c39d0b3e',
#      'author': {'email': '98070882+seryozha1989@users.noreply.github.com',
#       'name': 'seryozha1989'},
#      'message': 'BcqDGYLGShBhpybT.s',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/seryozha1989/-5999455317753235474/commits/2002063b8ecb80ccd5d9b448b3c5d411c39d0b3e'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882583',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 493805522,
#    'name': 'gbuehler/CoverageJSON',
#    'url': 'https://api.github.com/repos/gbuehler/CoverageJSON'},
#   'payload': {'push_id': 11514975020,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cd5bcdc6f6385b363d2c2adc9fb2332d594df323',
#    'before': 'afc6ef18e46112be618f70b9ae059d1c22673765',
#    'commits': [{'sha': 'cd5bcdc6f6385b363d2c2adc9fb2332d594df323',
#      'author': {'email': 'opengeospatial@users.noreply.github.com',
#       'name': 'opengeospatial'},
#      'message': 'Automated generation of HTML and PDF documents',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gbuehler/CoverageJSON/commits/cd5bcdc6f6385b363d2c2adc9fb2332d594df323'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882559',
#   'type': 'PushEvent',
#   'actor': {'id': 98070882,
#    'login': 'seryozha1989',
#    'display_login': 'seryozha1989',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seryozha1989',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98070882?'},
#   'repo': {'id': 457662221,
#    'name': 'seryozha1989/-477018030742834560',
#    'url': 'https://api.github.com/repos/seryozha1989/-477018030742834560'},
#   'payload': {'push_id': 11514974991,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '71a7383764ec3abb2c108a5167a97da585e344f9',
#    'before': '49744560b36e238736950eb8e90e9932e0c482db',
#    'commits': [{'sha': '71a7383764ec3abb2c108a5167a97da585e344f9',
#      'author': {'email': '98070882+seryozha1989@users.noreply.github.com',
#       'name': 'seryozha1989'},
#      'message': 'LBQoydLTRbNeA.s',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/seryozha1989/-477018030742834560/commits/71a7383764ec3abb2c108a5167a97da585e344f9'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882607',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 38041391,
#    'login': 'JasperO98',
#    'display_login': 'JasperO98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JasperO98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38041391?'},
#   'repo': {'id': 23992530,
#    'name': 'galaxyproject/tools-iuc',
#    'url': 'https://api.github.com/repos/galaxyproject/tools-iuc'},
#   'payload': {'action': 'created',
#    'review': {'id': 1163096447,
#     'node_id': 'PRR_kwDOAW4Y0s5FU3F_',
#     'user': {'login': 'JasperO98',
#      'id': 38041391,
#      'node_id': 'MDQ6VXNlcjM4MDQxMzkx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/38041391?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/JasperO98',
#      'html_url': 'https://github.com/JasperO98',
#      'followers_url': 'https://api.github.com/users/JasperO98/followers',
#      'following_url': 'https://api.github.com/users/JasperO98/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/JasperO98/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/JasperO98/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/JasperO98/subscriptions',
#      'organizations_url': 'https://api.github.com/users/JasperO98/orgs',
#      'repos_url': 'https://api.github.com/users/JasperO98/repos',
#      'events_url': 'https://api.github.com/users/JasperO98/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/JasperO98/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': '40e4d9b50c98f0ef7bc671a6348c5b91ad4f7db7',
#     'submitted_at': '2022-11-01T09:57:54Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/galaxyproject/tools-iuc/pull/4889#pullrequestreview-1163096447',
#     'pull_request_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/galaxyproject/tools-iuc/pull/4889#pullrequestreview-1163096447'},
#      'pull_request': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889',
#     'id': 1105567971,
#     'node_id': 'PR_kwDOAW4Y0s5B5aDj',
#     'html_url': 'https://github.com/galaxyproject/tools-iuc/pull/4889',
#     'diff_url': 'https://github.com/galaxyproject/tools-iuc/pull/4889.diff',
#     'patch_url': 'https://github.com/galaxyproject/tools-iuc/pull/4889.patch',
#     'issue_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/4889',
#     'number': 4889,
#     'state': 'open',
#     'locked': False,
#     'title': 'STAR add suggested parameter for Arriba --alignSJstitchMismatchNmax and add softclip option --chimOutType ',
#     'user': {'login': 'JasperO98',
#      'id': 38041391,
#      'node_id': 'MDQ6VXNlcjM4MDQxMzkx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/38041391?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/JasperO98',
#      'html_url': 'https://github.com/JasperO98',
#      'followers_url': 'https://api.github.com/users/JasperO98/followers',
#      'following_url': 'https://api.github.com/users/JasperO98/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/JasperO98/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/JasperO98/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/JasperO98/subscriptions',
#      'organizations_url': 'https://api.github.com/users/JasperO98/orgs',
#      'repos_url': 'https://api.github.com/users/JasperO98/repos',
#      'events_url': 'https://api.github.com/users/JasperO98/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/JasperO98/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'FOR CONTRIBUTOR:\r\n* [x] - I have read the [CONTRIBUTING.md](https://github.com/galaxyproject/tools-iuc/blob/master/CONTRIBUTING.md) document and this tool is appropriate for the tools-iuc repo.\r\n* [x] - License permits unrestricted use (educational + commercial)\r\n* [ ] - This PR adds a new tool or tool collection\r\n* [x] - This PR updates an existing tool or tool collection\r\n* [ ] - This PR does something else (explain below)\r\n\r\nI have added the parameters `--alignSJstitchMismatchNmax` and `--chimOutType` parameters are missing, which are recommended parameters for the fusion gene detection tool Arriba. All recommended parameters for Arriba are available, see [documentation](https://arriba.readthedocs.io/en/latest/workflow/).  This pull request is related to #4848 where Arriba can control STAR to automatically use the correct parameters. This had some issues so it would be better to expose the arguments in STAR, which are added here.',
#     'created_at': '2022-10-31T16:01:58Z',
#     'updated_at': '2022-11-01T09:57:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '0d76c0efcabe8cc76bce5b5ef2bb4884d2057512',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889/commits',
#     'review_comments_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889/comments',
#     'review_comment_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/4889/comments',
#     'statuses_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/statuses/dd97e4289faadf068d576bc0e8c9cfa9d209984c',
#     'head': {'label': 'JasperO98:STAR_add_twopass1readsN',
#      'ref': 'STAR_add_twopass1readsN',
#      'sha': 'dd97e4289faadf068d576bc0e8c9cfa9d209984c',
#      'user': {'login': 'JasperO98',
#       'id': 38041391,
#       'node_id': 'MDQ6VXNlcjM4MDQxMzkx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/38041391?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/JasperO98',
#       'html_url': 'https://github.com/JasperO98',
#       'followers_url': 'https://api.github.com/users/JasperO98/followers',
#       'following_url': 'https://api.github.com/users/JasperO98/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/JasperO98/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/JasperO98/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/JasperO98/subscriptions',
#       'organizations_url': 'https://api.github.com/users/JasperO98/orgs',
#       'repos_url': 'https://api.github.com/users/JasperO98/repos',
#       'events_url': 'https://api.github.com/users/JasperO98/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/JasperO98/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 450442037,
#       'node_id': 'R_kgDOGtkzNQ',
#       'name': 'tools-iuc',
#       'full_name': 'JasperO98/tools-iuc',
#       'private': False,
#       'owner': {'login': 'JasperO98',
#        'id': 38041391,
#        'node_id': 'MDQ6VXNlcjM4MDQxMzkx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/38041391?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/JasperO98',
#        'html_url': 'https://github.com/JasperO98',
#        'followers_url': 'https://api.github.com/users/JasperO98/followers',
#        'following_url': 'https://api.github.com/users/JasperO98/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/JasperO98/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/JasperO98/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/JasperO98/subscriptions',
#        'organizations_url': 'https://api.github.com/users/JasperO98/orgs',
#        'repos_url': 'https://api.github.com/users/JasperO98/repos',
#        'events_url': 'https://api.github.com/users/JasperO98/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/JasperO98/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/JasperO98/tools-iuc',
#       'description': 'Tool Shed repositories maintained by the Intergalactic Utilities Commission',
#       'fork': True,
#       'url': 'https://api.github.com/repos/JasperO98/tools-iuc',
#       'forks_url': 'https://api.github.com/repos/JasperO98/tools-iuc/forks',
#       'keys_url': 'https://api.github.com/repos/JasperO98/tools-iuc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/JasperO98/tools-iuc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/JasperO98/tools-iuc/teams',
#       'hooks_url': 'https://api.github.com/repos/JasperO98/tools-iuc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/JasperO98/tools-iuc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/JasperO98/tools-iuc/events',
#       'assignees_url': 'https://api.github.com/repos/JasperO98/tools-iuc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/JasperO98/tools-iuc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/JasperO98/tools-iuc/tags',
#       'blobs_url': 'https://api.github.com/repos/JasperO98/tools-iuc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/JasperO98/tools-iuc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/JasperO98/tools-iuc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/JasperO98/tools-iuc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/JasperO98/tools-iuc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/JasperO98/tools-iuc/languages',
#       'stargazers_url': 'https://api.github.com/repos/JasperO98/tools-iuc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/JasperO98/tools-iuc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/JasperO98/tools-iuc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/JasperO98/tools-iuc/subscription',
#       'commits_url': 'https://api.github.com/repos/JasperO98/tools-iuc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/JasperO98/tools-iuc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/JasperO98/tools-iuc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/JasperO98/tools-iuc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/JasperO98/tools-iuc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/JasperO98/tools-iuc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/JasperO98/tools-iuc/merges',
#       'archive_url': 'https://api.github.com/repos/JasperO98/tools-iuc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/JasperO98/tools-iuc/downloads',
#       'issues_url': 'https://api.github.com/repos/JasperO98/tools-iuc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/JasperO98/tools-iuc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/JasperO98/tools-iuc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/JasperO98/tools-iuc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/JasperO98/tools-iuc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/JasperO98/tools-iuc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/JasperO98/tools-iuc/deployments',
#       'created_at': '2022-01-21T10:10:13Z',
#       'updated_at': '2022-10-12T12:55:42Z',
#       'pushed_at': '2022-11-01T09:54:17Z',
#       'git_url': 'git://github.com/JasperO98/tools-iuc.git',
#       'ssh_url': 'git@github.com:JasperO98/tools-iuc.git',
#       'clone_url': 'https://github.com/JasperO98/tools-iuc.git',
#       'svn_url': 'https://github.com/JasperO98/tools-iuc',
#       'homepage': 'https://galaxyproject.org/iuc',
#       'size': 992042,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'galaxyproject:master',
#      'ref': 'master',
#      'sha': '05505898035b41c07461dc0eecec61699ecbcf41',
#      'user': {'login': 'galaxyproject',
#       'id': 7937847,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5Mzc4NDc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7937847?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/galaxyproject',
#       'html_url': 'https://github.com/galaxyproject',
#       'followers_url': 'https://api.github.com/users/galaxyproject/followers',
#       'following_url': 'https://api.github.com/users/galaxyproject/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/galaxyproject/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/galaxyproject/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/galaxyproject/subscriptions',
#       'organizations_url': 'https://api.github.com/users/galaxyproject/orgs',
#       'repos_url': 'https://api.github.com/users/galaxyproject/repos',
#       'events_url': 'https://api.github.com/users/galaxyproject/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/galaxyproject/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 23992530,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzk5MjUzMA==',
#       'name': 'tools-iuc',
#       'full_name': 'galaxyproject/tools-iuc',
#       'private': False,
#       'owner': {'login': 'galaxyproject',
#        'id': 7937847,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5Mzc4NDc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7937847?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/galaxyproject',
#        'html_url': 'https://github.com/galaxyproject',
#        'followers_url': 'https://api.github.com/users/galaxyproject/followers',
#        'following_url': 'https://api.github.com/users/galaxyproject/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/galaxyproject/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/galaxyproject/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/galaxyproject/subscriptions',
#        'organizations_url': 'https://api.github.com/users/galaxyproject/orgs',
#        'repos_url': 'https://api.github.com/users/galaxyproject/repos',
#        'events_url': 'https://api.github.com/users/galaxyproject/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/galaxyproject/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/galaxyproject/tools-iuc',
#       'description': 'Tool Shed repositories maintained by the Intergalactic Utilities Commission',
#       'fork': False,
#       'url': 'https://api.github.com/repos/galaxyproject/tools-iuc',
#       'forks_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/forks',
#       'keys_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/teams',
#       'hooks_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/events',
#       'assignees_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/tags',
#       'blobs_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/languages',
#       'stargazers_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/subscription',
#       'commits_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/merges',
#       'archive_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/downloads',
#       'issues_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/galaxyproject/tools-iuc/deployments',
#       'created_at': '2014-09-13T11:18:49Z',
#       'updated_at': '2022-10-17T16:38:27Z',
#       'pushed_at': '2022-11-01T09:54:20Z',
#       'git_url': 'git://github.com/galaxyproject/tools-iuc.git',
#       'ssh_url': 'git@github.com:galaxyproject/tools-iuc.git',
#       'clone_url': 'https://github.com/galaxyproject/tools-iuc.git',
#       'svn_url': 'https://github.com/galaxyproject/tools-iuc',
#       'homepage': 'https://galaxyproject.org/iuc',
#       'size': 992254,
#       'stargazers_count': 139,
#       'watchers_count': 139,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 344,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 510,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest',
#        'iuc',
#        'tools',
#        'toolshed',
#        'usegalaxy',
#        'wrappers'],
#       'visibility': 'public',
#       'forks': 344,
#       'open_issues': 510,
#       'watchers': 139,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889'},
#      'html': {'href': 'https://github.com/galaxyproject/tools-iuc/pull/4889'},
#      'issue': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/4889'},
#      'comments': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/issues/4889/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/pulls/4889/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/galaxyproject/tools-iuc/statuses/dd97e4289faadf068d576bc0e8c9cfa9d209984c'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 7937847,
#    'login': 'galaxyproject',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/galaxyproject',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7937847?'}},
#  {'id': '24953882548',
#   'type': 'CreateEvent',
#   'actor': {'id': 117162861,
#    'login': 'SmurfetteIs',
#    'display_login': 'SmurfetteIs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SmurfetteIs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117162861?'},
#   'repo': {'id': 560352816,
#    'name': 'SmurfetteIs/Binary-Workflow-Pipeline',
#    'url': 'https://api.github.com/repos/SmurfetteIs/Binary-Workflow-Pipeline'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Rust-NG Binary Workflow Pipeline',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882517',
#   'type': 'PushEvent',
#   'actor': {'id': 104618459,
#    'login': 'bendegalab',
#    'display_login': 'bendegalab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bendegalab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104618459?'},
#   'repo': {'id': 549212013,
#    'name': 'gablechain/gable',
#    'url': 'https://api.github.com/repos/gablechain/gable'},
#   'payload': {'push_id': 11514975006,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gable-testnet',
#    'head': '3b6603f9b6664a03305239424e779a93193c775a',
#    'before': '539083c36aab219d27b9aea139ada80b00725a8a',
#    'commits': [{'sha': '3b6603f9b6664a03305239424e779a93193c775a',
#      'author': {'email': 'ben@degalabs.fi', 'name': 'ben'},
#      'message': 'update func spec',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gablechain/gable/commits/3b6603f9b6664a03305239424e779a93193c775a'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 115541100,
#    'login': 'gablechain',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gablechain',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115541100?'}},
#  {'id': '24953882567',
#   'type': 'IssuesEvent',
#   'actor': {'id': 32935233,
#    'login': 'kjappelbaum',
#    'display_login': 'kjappelbaum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kjappelbaum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32935233?'},
#   'repo': {'id': 333360371,
#    'name': 'kjappelbaum/moffragmentor',
#    'url': 'https://api.github.com/repos/kjappelbaum/moffragmentor'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136',
#     'repository_url': 'https://api.github.com/repos/kjappelbaum/moffragmentor',
#     'labels_url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136/comments',
#     'events_url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136/events',
#     'html_url': 'https://github.com/kjappelbaum/moffragmentor/issues/136',
#     'id': 1431166848,
#     'node_id': 'I_kwDOE96s885VTd-A',
#     'number': 136,
#     'title': 'set branching indices on `MOF` level ',
#     'user': {'login': 'kjappelbaum',
#      'id': 32935233,
#      'node_id': 'MDQ6VXNlcjMyOTM1MjMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32935233?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kjappelbaum',
#      'html_url': 'https://github.com/kjappelbaum',
#      'followers_url': 'https://api.github.com/users/kjappelbaum/followers',
#      'following_url': 'https://api.github.com/users/kjappelbaum/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kjappelbaum/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kjappelbaum/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kjappelbaum/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kjappelbaum/orgs',
#      'repos_url': 'https://api.github.com/users/kjappelbaum/repos',
#      'events_url': 'https://api.github.com/users/kjappelbaum/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kjappelbaum/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-11-01T09:57:54Z',
#     'updated_at': '2022-11-01T09:57:54Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kjappelbaum/moffragmentor/issues/136/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882580',
#   'type': 'CreateEvent',
#   'actor': {'id': 82135647,
#    'login': 'xuhpppp',
#    'display_login': 'xuhpppp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xuhpppp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82135647?'},
#   'repo': {'id': 560346667,
#    'name': 'xuhpppp/DrowsinessDetectionPython',
#    'url': 'https://api.github.com/repos/xuhpppp/DrowsinessDetectionPython'},
#   'payload': {'ref': 'exp/scaleFill',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882544',
#   'type': 'WatchEvent',
#   'actor': {'id': 33859920,
#    'login': 'Leekeey',
#    'display_login': 'Leekeey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leekeey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33859920?'},
#   'repo': {'id': 559536070,
#    'name': 'H4de5-7/powershell-bypass',
#    'url': 'https://api.github.com/repos/H4de5-7/powershell-bypass'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882524',
#   'type': 'PushEvent',
#   'actor': {'id': 29997978,
#    'login': 'Luckynmc',
#    'display_login': 'Luckynmc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Luckynmc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29997978?'},
#   'repo': {'id': 531442211,
#    'name': 'Luckynmc/test',
#    'url': 'https://api.github.com/repos/Luckynmc/test'},
#   'payload': {'push_id': 11514974993,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '906dea62c9ec91480a36a2841eb887fb9f4d606f',
#    'before': 'dfc5922ec7bcaa7288b2168304a69a25087205b7',
#    'commits': [{'sha': '906dea62c9ec91480a36a2841eb887fb9f4d606f',
#      'author': {'email': '924929156@qq.com', 'name': 'Luckynmc'},
#      'message': 'inits',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Luckynmc/test/commits/906dea62c9ec91480a36a2841eb887fb9f4d606f'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882523',
#   'type': 'PushEvent',
#   'actor': {'id': 7370336,
#    'login': 'odinr',
#    'display_login': 'odinr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/odinr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7370336?'},
#   'repo': {'id': 371285039,
#    'name': 'equinor/fusion-framework',
#    'url': 'https://api.github.com/repos/equinor/fusion-framework'},
#   'payload': {'push_id': 11514974974,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f2f41d230538778af6a20d7ed994bfdba91d53e3',
#    'before': '7d5c5892cc51337c22f6562ffbcc3a3daf3373f5',
#    'commits': [{'sha': 'f2f41d230538778af6a20d7ed994bfdba91d53e3',
#      'author': {'email': 'odin.rochmann@gmail.com',
#       'name': 'Odin Thomas Rochmann'},
#      'message': 'docs: update roadmap',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/equinor/fusion-framework/commits/f2f41d230538778af6a20d7ed994bfdba91d53e3'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 525862,
#    'login': 'equinor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/equinor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/525862?'}},
#  {'id': '24953882495',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 447965283,
#    'name': 'lb-lewisham/covid-dashboard',
#    'url': 'https://api.github.com/repos/lb-lewisham/covid-dashboard'},
#   'payload': {'push_id': 11514974946,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '1ab9933323925c182153ada3303b5a394bff25da',
#    'before': 'c2d4d1b44dd6f4525c754a8f0282b4814f00340b',
#    'commits': [{'sha': '1ab9933323925c182153ada3303b5a394bff25da',
#      'author': {'email': 'martin-liad@users.noreply.github.com',
#       'name': 'martin-liad'},
#      'message': 'deploy: e7f53cb60f34ce0907afbe3c9fc8fb8146b4078e',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lb-lewisham/covid-dashboard/commits/1ab9933323925c182153ada3303b5a394bff25da'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 93042302,
#    'login': 'lb-lewisham',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lb-lewisham',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93042302?'}},
#  {'id': '24953882549',
#   'type': 'CreateEvent',
#   'actor': {'id': 1155441,
#    'login': 'miickel',
#    'display_login': 'miickel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miickel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1155441?'},
#   'repo': {'id': 560352813,
#    'name': 'miickel/StyleGAN2',
#    'url': 'https://api.github.com/repos/miickel/StyleGAN2'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882540',
#   'type': 'WatchEvent',
#   'actor': {'id': 16426260,
#    'login': 'chj9',
#    'display_login': 'chj9',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chj9',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16426260?'},
#   'repo': {'id': 62607227,
#    'name': 'yangshun/tech-interview-handbook',
#    'url': 'https://api.github.com/repos/yangshun/tech-interview-handbook'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882505',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 51714798,
#    'login': 'juliusmarminge',
#    'display_login': 'juliusmarminge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juliusmarminge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51714798?'},
#   'repo': {'id': 543585776,
#    'name': 'agreeto/agreeto',
#    'url': 'https://api.github.com/repos/agreeto/agreeto'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/agreeto/agreeto/issues/6',
#     'repository_url': 'https://api.github.com/repos/agreeto/agreeto',
#     'labels_url': 'https://api.github.com/repos/agreeto/agreeto/issues/6/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/agreeto/agreeto/issues/6/comments',
#     'events_url': 'https://api.github.com/repos/agreeto/agreeto/issues/6/events',
#     'html_url': 'https://github.com/agreeto/agreeto/pull/6',
#     'id': 1428214970,
#     'node_id': 'PR_kwDOIGZ18M5BzLPj',
#     'number': 6,
#     'title': 'feat(extension, outlook, web): Add authentication',
#     'user': {'login': 'p6l-richard',
#      'id': 18185649,
#      'node_id': 'MDQ6VXNlcjE4MTg1NjQ5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18185649?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/p6l-richard',
#      'html_url': 'https://github.com/p6l-richard',
#      'followers_url': 'https://api.github.com/users/p6l-richard/followers',
#      'following_url': 'https://api.github.com/users/p6l-richard/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/p6l-richard/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/p6l-richard/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/p6l-richard/subscriptions',
#      'organizations_url': 'https://api.github.com/users/p6l-richard/orgs',
#      'repos_url': 'https://api.github.com/users/p6l-richard/repos',
#      'events_url': 'https://api.github.com/users/p6l-richard/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/p6l-richard/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2022-10-29T11:08:57Z',
#     'updated_at': '2022-11-01T09:57:54Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'draft': True,
#     'pull_request': {'url': 'https://api.github.com/repos/agreeto/agreeto/pulls/6',
#      'html_url': 'https://github.com/agreeto/agreeto/pull/6',
#      'diff_url': 'https://github.com/agreeto/agreeto/pull/6.diff',
#      'patch_url': 'https://github.com/agreeto/agreeto/pull/6.patch',
#      'merged_at': None},
# ...
#    'url': 'https://api.github.com/repos/jliew/silpostores'},
#   'payload': {'push_id': 11514974989,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bd72d6472bb109577b48c9de1b79a1d2f7278d65',
#    'before': '675cb22b3f3974bee0b1b714b8aeab8e63bcb0e5',
#    'commits': [{'sha': 'bd72d6472bb109577b48c9de1b79a1d2f7278d65',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated Publisher'},
#      'message': 'Automated publish: Tue Nov  1 09:57:52 UTC 2022 675cb22b3f3974bee0b1b714b8aeab8e63bcb0e5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jliew/silpostores/commits/bd72d6472bb109577b48c9de1b79a1d2f7278d65'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882476',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 431382886,
#    'name': 'manny27416/docs',
#    'url': 'https://api.github.com/repos/manny27416/docs'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/types/lodash-4.14.186',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882499',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 353600147,
#    'name': 'brocjad/pub_hofs',
#    'url': 'https://api.github.com/repos/brocjad/pub_hofs'},
#   'payload': {'push_id': 11514974990,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2dba418a7008f67760bef71ef9af856a1b0d23a8',
#    'before': '112fbf9d7c9d2cbc8b7067992d192a6893a8997e',
#    'commits': [{'sha': '2dba418a7008f67760bef71ef9af856a1b0d23a8',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'update_log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brocjad/pub_hofs/commits/2dba418a7008f67760bef71ef9af856a1b0d23a8'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882490',
#   'type': 'CreateEvent',
#   'actor': {'id': 1155441,
#    'login': 'miickel',
#    'display_login': 'miickel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miickel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1155441?'},
#   'repo': {'id': 560352813,
#    'name': 'miickel/StyleGAN2',
#    'url': 'https://api.github.com/repos/miickel/StyleGAN2'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882445',
#   'type': 'PushEvent',
#   'actor': {'id': 112394028,
#    'login': 'Daan071',
#    'display_login': 'Daan071',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Daan071',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112394028?'},
#   'repo': {'id': 530188942,
#    'name': 'Daan071/Daan071.github.io',
#    'url': 'https://api.github.com/repos/Daan071/Daan071.github.io'},
#   'payload': {'push_id': 11514974950,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '839cb9f903eada418805b961d99a5a92de9f2dc9',
#    'before': 'b27da4e8a9aef6b58b8e4290e0ba25c4bd89d418',
#    'commits': [{'sha': '839cb9f903eada418805b961d99a5a92de9f2dc9',
#      'author': {'email': '112394028+Daan071@users.noreply.github.com',
#       'name': 'MaximusPrincipus'},
#      'message': 'ye',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Daan071/Daan071.github.io/commits/839cb9f903eada418805b961d99a5a92de9f2dc9'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882433',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'push_id': 11514974956,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '75b60c2174555397fe24e8e20c669848992b6860',
#    'before': '1edb2d5cd2e694eccd5821b390cfb660ae6264f3',
#    'commits': [{'sha': '75b60c2174555397fe24e8e20c669848992b6860',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2022-11-01 18:57, 顔芸先輩式・乖離剣エア Ver2.0 - Royal・Fragment - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/75b60c2174555397fe24e8e20c669848992b6860'}]},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882402',
#   'type': 'IssuesEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 555465556,
#    'name': 'hvuddagi/ActionsTest',
#    'url': 'https://api.github.com/repos/hvuddagi/ActionsTest'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115',
#     'repository_url': 'https://api.github.com/repos/hvuddagi/ActionsTest',
#     'labels_url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115/comments',
#     'events_url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115/events',
#     'html_url': 'https://github.com/hvuddagi/ActionsTest/issues/4115',
#     'id': 1431166840,
#     'node_id': 'I_kwDOIRu7VM5VTd94',
#     'number': 4115,
#     'title': 'Automated issue for commit: 8d1afce6313e85ba0e42a05f2e0d1aff38d36ee2',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-11-01T09:57:53Z',
#     'updated_at': '2022-11-01T09:57:53Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'This issue was automatically created by the GitHub Action workflow **ENV Variables**. \n\n The commit hash was: _8d1afce6313e85ba0e42a05f2e0d1aff38d36ee2_.',
#     'reactions': {'url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/hvuddagi/ActionsTest/issues/4115/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'},
#  {'id': '24953882455',
#   'type': 'ForkEvent',
#   'actor': {'id': 56889604,
#    'login': 'GzdeGrlr',
#    'display_login': 'GzdeGrlr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GzdeGrlr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56889604?'},
#   'repo': {'id': 560190457,
#    'name': 'Workintech/FSWeb-S2G2-callback-ve-array',
#    'url': 'https://api.github.com/repos/Workintech/FSWeb-S2G2-callback-ve-array'},
#   'payload': {'forkee': {'id': 560352819,
#     'node_id': 'R_kgDOIWZOMw',
#     'name': 'FSWeb-S2G2-callback-ve-array',
#     'full_name': 'GzdeGrlr/FSWeb-S2G2-callback-ve-array',
#     'private': False,
#     'owner': {'login': 'GzdeGrlr',
#      'id': 56889604,
#      'node_id': 'MDQ6VXNlcjU2ODg5NjA0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/56889604?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GzdeGrlr',
#      'html_url': 'https://github.com/GzdeGrlr',
#      'followers_url': 'https://api.github.com/users/GzdeGrlr/followers',
#      'following_url': 'https://api.github.com/users/GzdeGrlr/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GzdeGrlr/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GzdeGrlr/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GzdeGrlr/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GzdeGrlr/orgs',
#      'repos_url': 'https://api.github.com/users/GzdeGrlr/repos',
#      'events_url': 'https://api.github.com/users/GzdeGrlr/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GzdeGrlr/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/GzdeGrlr/FSWeb-S2G2-callback-ve-array',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array',
#     'forks_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/forks',
#     'keys_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/teams',
#     'hooks_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/hooks',
#     'issue_events_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/events',
#     'assignees_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/tags',
#     'blobs_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/languages',
#     'stargazers_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/stargazers',
#     'contributors_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/contributors',
#     'subscribers_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/subscribers',
#     'subscription_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/subscription',
#     'commits_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/merges',
#     'archive_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/downloads',
#     'issues_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/GzdeGrlr/FSWeb-S2G2-callback-ve-array/deployments',
#     'created_at': '2022-11-01T09:57:53Z',
#     'updated_at': '2022-10-31T23:44:25Z',
#     'pushed_at': '2022-10-31T23:44:21Z',
#     'git_url': 'git://github.com/GzdeGrlr/FSWeb-S2G2-callback-ve-array.git',
#     'ssh_url': 'git@github.com:GzdeGrlr/FSWeb-S2G2-callback-ve-array.git',
#     'clone_url': 'https://github.com/GzdeGrlr/FSWeb-S2G2-callback-ve-array.git',
#     'svn_url': 'https://github.com/GzdeGrlr/FSWeb-S2G2-callback-ve-array',
#     'homepage': None,
#     'size': 56,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z',
#   'org': {'id': 108612140,
#    'login': 'Workintech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Workintech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108612140?'}},
#  {'id': '24953882401',
#   'type': 'DeleteEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 390217875,
#    'name': 'meganmackerwaler/banacle',
#    'url': 'https://api.github.com/repos/meganmackerwaler/banacle'},
#   'payload': {'ref': 'encryptSrv_3.0.0143.jar',
#    'ref_type': 'tag',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-01T09:57:54Z'}]

# %%
# How many events are we looking at?
len(github_response)
# Out:
# 30

# %%
# What are the keys in the first event?
github_response[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'])

# %%
# We can see that 'repo' is another subdictionary.
# What are the keys in the 'repo' subdictionary?
github_response[0]['repo'].keys()
# Out:
# dict_keys(['id', 'name', 'url'])

# %%
# What's the value for the key 'name' in 'repo'?
github_response[0]['repo']['name']
# Out:
# 'Prash28/C-'

# %% [markdown]
# #### Transforming a JSON into a DataFrame

# %% [markdown]
# ##### Option 1: pd.DataFrame()

# %%
# Turn it into a pandas DataFrame.
pd.DataFrame(github_response)
# Out:
#              id                    type  \
# 0   24953882621             CreateEvent
# 1   24953882586       IssueCommentEvent
# 2   24953882537               PushEvent
# 3   24953882584             CreateEvent
# 4   24953882560               PushEvent
# 5   24953882583               PushEvent
# 6   24953882559               PushEvent
# 7   24953882607  PullRequestReviewEvent
# 8   24953882548             CreateEvent
# 9   24953882517               PushEvent
# 10  24953882567             IssuesEvent
# 11  24953882580             CreateEvent
# 12  24953882544              WatchEvent
# 13  24953882524               PushEvent
# 14  24953882523               PushEvent
# 15  24953882495               PushEvent
# 16  24953882549             CreateEvent
# 17  24953882540              WatchEvent
# 18  24953882505       IssueCommentEvent
# 19  24953882508               PushEvent
# 20  24953882491               PushEvent
# 21  24953882492               PushEvent
# 22  24953882476             DeleteEvent
# 23  24953882499               PushEvent
# 24  24953882490             CreateEvent
# 25  24953882445               PushEvent
# 26  24953882433               PushEvent
# 27  24953882402             IssuesEvent
# 28  24953882455               ForkEvent
# 29  24953882401             DeleteEvent
#
#                                                 actor  \
# 0   {'id': 37222518, 'login': 'Prash28', 'display_...
# 1   {'id': 7776826, 'login': 'giadefa', 'display_l...
# 2   {'id': 116969040, 'login': 'Zqxg', 'display_lo...
# 3   {'id': 95440233, 'login': 'rialele', 'display_...
# 4   {'id': 98070882, 'login': 'seryozha1989', 'dis...
# 5   {'id': 41898282, 'login': 'github-actions[bot]...
# 6   {'id': 98070882, 'login': 'seryozha1989', 'dis...
# 7   {'id': 38041391, 'login': 'JasperO98', 'displa...
# 8   {'id': 117162861, 'login': 'SmurfetteIs', 'dis...
# 9   {'id': 104618459, 'login': 'bendegalab', 'disp...
# 10  {'id': 32935233, 'login': 'kjappelbaum', 'disp...
# 11  {'id': 82135647, 'login': 'xuhpppp', 'display_...
# 12  {'id': 33859920, 'login': 'Leekeey', 'display_...
# 13  {'id': 29997978, 'login': 'Luckynmc', 'display...
# 14  {'id': 7370336, 'login': 'odinr', 'display_log...
# 15  {'id': 41898282, 'login': 'github-actions[bot]...
# 16  {'id': 1155441, 'login': 'miickel', 'display_l...
# 17  {'id': 16426260, 'login': 'chj9', 'display_log...
# 18  {'id': 51714798, 'login': 'juliusmarminge', 'd...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 105747344, 'login': 'rajramk12', 'displ...
# 21  {'id': 41898282, 'login': 'github-actions[bot]...
# 22  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 23  {'id': 41898282, 'login': 'github-actions[bot]...
# 24  {'id': 1155441, 'login': 'miickel', 'display_l...
# 25  {'id': 112394028, 'login': 'Daan071', 'display...
# 26  {'id': 43733305, 'login': 'yanonono', 'display...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 56889604, 'login': 'GzdeGrlr', 'display...
# 29  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                  repo  \
# 0   {'id': 560351309, 'name': 'Prash28/C-', 'url':...
# 1   {'id': 356331061, 'name': 'torchmd/torchmd-net...
# 2   {'id': 559293948, 'name': 'Zqxg/Tasks', 'url':...
# 3   {'id': 560352820, 'name': 'rialele/blood-bank-...
# 4   {'id': 458034268, 'name': 'seryozha1989/-59994...
# 5   {'id': 493805522, 'name': 'gbuehler/CoverageJS...
# 6   {'id': 457662221, 'name': 'seryozha1989/-47701...
# 7   {'id': 23992530, 'name': 'galaxyproject/tools-...
# 8   {'id': 560352816, 'name': 'SmurfetteIs/Binary-...
# 9   {'id': 549212013, 'name': 'gablechain/gable', ...
# 10  {'id': 333360371, 'name': 'kjappelbaum/moffrag...
# 11  {'id': 560346667, 'name': 'xuhpppp/DrowsinessD...
# 12  {'id': 559536070, 'name': 'H4de5-7/powershell-...
# 13  {'id': 531442211, 'name': 'Luckynmc/test', 'ur...
# 14  {'id': 371285039, 'name': 'equinor/fusion-fram...
# 15  {'id': 447965283, 'name': 'lb-lewisham/covid-d...
# 16  {'id': 560352813, 'name': 'miickel/StyleGAN2',...
# 17  {'id': 62607227, 'name': 'yangshun/tech-interv...
# 18  {'id': 543585776, 'name': 'agreeto/agreeto', '...
# 19  {'id': 314055004, 'name': 'bigwing/upptime', '...
# 20  {'id': 560323187, 'name': 'rajramk12/turboapp'...
# 21  {'id': 470356991, 'name': 'jliew/silpostores',...
# 22  {'id': 431382886, 'name': 'manny27416/docs', '...
# 23  {'id': 353600147, 'name': 'brocjad/pub_hofs', ...
# 24  {'id': 560352813, 'name': 'miickel/StyleGAN2',...
# 25  {'id': 530188942, 'name': 'Daan071/Daan071.git...
# 26  {'id': 183440182, 'name': 'yanonono/booth-upda...
# 27  {'id': 555465556, 'name': 'hvuddagi/ActionsTes...
# 28  {'id': 560190457, 'name': 'Workintech/FSWeb-S2...
# 29  {'id': 390217875, 'name': 'meganmackerwaler/ba...
#
#                                               payload  public  \
# 0   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 1   {'action': 'created', 'issue': {'url': 'https:...    True
# 2   {'push_id': 11514974977, 'size': 1, 'distinct_...    True
# 3   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 4   {'push_id': 11514975017, 'size': 1, 'distinct_...    True
# 5   {'push_id': 11514975020, 'size': 1, 'distinct_...    True
# 6   {'push_id': 11514974991, 'size': 1, 'distinct_...    True
# 7   {'action': 'created', 'review': {'id': 1163096...    True
# 8   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 9   {'push_id': 11514975006, 'size': 1, 'distinct_...    True
# 10  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 11  {'ref': 'exp/scaleFill', 'ref_type': 'branch',...    True
# 12                              {'action': 'started'}    True
# 13  {'push_id': 11514974993, 'size': 1, 'distinct_...    True
# 14  {'push_id': 11514974974, 'size': 1, 'distinct_...    True
# 15  {'push_id': 11514974946, 'size': 1, 'distinct_...    True
# 16  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 17                              {'action': 'started'}    True
# 18  {'action': 'created', 'issue': {'url': 'https:...    True
# 19  {'push_id': 11514975001, 'size': 1, 'distinct_...    True
# 20  {'push_id': 11514974992, 'size': 1, 'distinct_...    True
# 21  {'push_id': 11514974989, 'size': 1, 'distinct_...    True
# 22  {'ref': 'dependabot/npm_and_yarn/types/lodash-...    True
# 23  {'push_id': 11514974990, 'size': 1, 'distinct_...    True
# 24  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 25  {'push_id': 11514974950, 'size': 1, 'distinct_...    True
# 26  {'push_id': 11514974956, 'size': 1, 'distinct_...    True
# 27  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 28  {'forkee': {'id': 560352819, 'node_id': 'R_kgD...    True
# 29  {'ref': 'encryptSrv_3.0.0143.jar', 'ref_type':...    True
#
#               created_at                                                org
# 0   2022-11-01T09:57:54Z                                                NaN
# 1   2022-11-01T09:57:54Z  {'id': 71184047, 'login': 'torchmd', 'gravatar...
# 2   2022-11-01T09:57:54Z                                                NaN
# 3   2022-11-01T09:57:54Z                                                NaN
# 4   2022-11-01T09:57:54Z                                                NaN
# 5   2022-11-01T09:57:54Z                                                NaN
# 6   2022-11-01T09:57:54Z                                                NaN
# 7   2022-11-01T09:57:54Z  {'id': 7937847, 'login': 'galaxyproject', 'gra...
# 8   2022-11-01T09:57:54Z                                                NaN
# 9   2022-11-01T09:57:54Z  {'id': 115541100, 'login': 'gablechain', 'grav...
# 10  2022-11-01T09:57:54Z                                                NaN
# 11  2022-11-01T09:57:54Z                                                NaN
# 12  2022-11-01T09:57:54Z                                                NaN
# 13  2022-11-01T09:57:54Z                                                NaN
# 14  2022-11-01T09:57:54Z  {'id': 525862, 'login': 'equinor', 'gravatar_i...
# 15  2022-11-01T09:57:54Z  {'id': 93042302, 'login': 'lb-lewisham', 'grav...
# 16  2022-11-01T09:57:54Z                                                NaN
# 17  2022-11-01T09:57:54Z                                                NaN
# 18  2022-11-01T09:57:54Z  {'id': 98811484, 'login': 'agreeto', 'gravatar...
# 19  2022-11-01T09:57:54Z  {'id': 13835088, 'login': 'bigwing', 'gravatar...
# 20  2022-11-01T09:57:54Z                                                NaN
# 21  2022-11-01T09:57:54Z                                                NaN
# 22  2022-11-01T09:57:54Z                                                NaN
# 23  2022-11-01T09:57:54Z                                                NaN
# 24  2022-11-01T09:57:54Z                                                NaN
# 25  2022-11-01T09:57:54Z                                                NaN
# 26  2022-11-01T09:57:54Z                                                NaN
# 27  2022-11-01T09:57:54Z                                                NaN
# 28  2022-11-01T09:57:54Z  {'id': 108612140, 'login': 'Workintech', 'grav...
# 29  2022-11-01T09:57:54Z                                                NaN

# %% [markdown]
# ##### Option 2: pd.json_normalize()
# You may notice above that many columns still contain dictionaries as values. We can correct this using json_normalize().
#
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
pd.json_normalize(github_response)
# Out:
#              id                    type  public            created_at  \
# 0   24953882621             CreateEvent    True  2022-11-01T09:57:54Z
# 1   24953882586       IssueCommentEvent    True  2022-11-01T09:57:54Z
# 2   24953882537               PushEvent    True  2022-11-01T09:57:54Z
# 3   24953882584             CreateEvent    True  2022-11-01T09:57:54Z
# 4   24953882560               PushEvent    True  2022-11-01T09:57:54Z
# 5   24953882583               PushEvent    True  2022-11-01T09:57:54Z
# 6   24953882559               PushEvent    True  2022-11-01T09:57:54Z
# 7   24953882607  PullRequestReviewEvent    True  2022-11-01T09:57:54Z
# 8   24953882548             CreateEvent    True  2022-11-01T09:57:54Z
# 9   24953882517               PushEvent    True  2022-11-01T09:57:54Z
# 10  24953882567             IssuesEvent    True  2022-11-01T09:57:54Z
# 11  24953882580             CreateEvent    True  2022-11-01T09:57:54Z
# 12  24953882544              WatchEvent    True  2022-11-01T09:57:54Z
# 13  24953882524               PushEvent    True  2022-11-01T09:57:54Z
# 14  24953882523               PushEvent    True  2022-11-01T09:57:54Z
# 15  24953882495               PushEvent    True  2022-11-01T09:57:54Z
# 16  24953882549             CreateEvent    True  2022-11-01T09:57:54Z
# 17  24953882540              WatchEvent    True  2022-11-01T09:57:54Z
# 18  24953882505       IssueCommentEvent    True  2022-11-01T09:57:54Z
# 19  24953882508               PushEvent    True  2022-11-01T09:57:54Z
# 20  24953882491               PushEvent    True  2022-11-01T09:57:54Z
# 21  24953882492               PushEvent    True  2022-11-01T09:57:54Z
# 22  24953882476             DeleteEvent    True  2022-11-01T09:57:54Z
# 23  24953882499               PushEvent    True  2022-11-01T09:57:54Z
# 24  24953882490             CreateEvent    True  2022-11-01T09:57:54Z
# 25  24953882445               PushEvent    True  2022-11-01T09:57:54Z
# 26  24953882433               PushEvent    True  2022-11-01T09:57:54Z
# 27  24953882402             IssuesEvent    True  2022-11-01T09:57:54Z
# 28  24953882455               ForkEvent    True  2022-11-01T09:57:54Z
# 29  24953882401             DeleteEvent    True  2022-11-01T09:57:54Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0    37222518              Prash28             Prash28
# 1     7776826              giadefa             giadefa
# 2   116969040                 Zqxg                Zqxg
# 3    95440233              rialele             rialele
# 4    98070882         seryozha1989        seryozha1989
# 5    41898282  github-actions[bot]      github-actions
# 6    98070882         seryozha1989        seryozha1989
# 7    38041391            JasperO98           JasperO98
# 8   117162861          SmurfetteIs         SmurfetteIs
# 9   104618459           bendegalab          bendegalab
# 10   32935233          kjappelbaum         kjappelbaum
# 11   82135647              xuhpppp             xuhpppp
# 12   33859920              Leekeey             Leekeey
# 13   29997978             Luckynmc            Luckynmc
# 14    7370336                odinr               odinr
# 15   41898282  github-actions[bot]      github-actions
# 16    1155441              miickel             miickel
# 17   16426260                 chj9                chj9
# 18   51714798       juliusmarminge      juliusmarminge
# 19   41898282  github-actions[bot]      github-actions
# 20  105747344            rajramk12           rajramk12
# 21   41898282  github-actions[bot]      github-actions
# 22   49699333      dependabot[bot]          dependabot
# 23   41898282  github-actions[bot]      github-actions
# 24    1155441              miickel             miickel
# 25  112394028              Daan071             Daan071
# 26   43733305             yanonono            yanonono
# 27   41898282  github-actions[bot]      github-actions
# 28   56889604             GzdeGrlr            GzdeGrlr
# 29   41898282  github-actions[bot]      github-actions
#
#                                            actor.url  \
# 0               https://api.github.com/users/Prash28
# 1               https://api.github.com/users/giadefa
# 2                  https://api.github.com/users/Zqxg
# 3               https://api.github.com/users/rialele
# 4          https://api.github.com/users/seryozha1989
# 5   https://api.github.com/users/github-actions[bot]
# 6          https://api.github.com/users/seryozha1989
# 7             https://api.github.com/users/JasperO98
# 8           https://api.github.com/users/SmurfetteIs
# 9            https://api.github.com/users/bendegalab
# 10          https://api.github.com/users/kjappelbaum
# 11              https://api.github.com/users/xuhpppp
# 12              https://api.github.com/users/Leekeey
# 13             https://api.github.com/users/Luckynmc
# 14                https://api.github.com/users/odinr
# 15  https://api.github.com/users/github-actions[bot]
# 16              https://api.github.com/users/miickel
# 17                 https://api.github.com/users/chj9
# 18       https://api.github.com/users/juliusmarminge
# 19  https://api.github.com/users/github-actions[bot]
# 20            https://api.github.com/users/rajramk12
# 21  https://api.github.com/users/github-actions[bot]
# 22      https://api.github.com/users/dependabot[bot]
# 23  https://api.github.com/users/github-actions[bot]
# 24              https://api.github.com/users/miickel
# 25              https://api.github.com/users/Daan071
# 26             https://api.github.com/users/yanonono
# 27  https://api.github.com/users/github-actions[bot]
# 28             https://api.github.com/users/GzdeGrlr
# 29  https://api.github.com/users/github-actions[bot]
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/37222518?  ...
# 1    https://avatars.githubusercontent.com/u/7776826?  ...
# 2   https://avatars.githubusercontent.com/u/116969...  ...
# 3   https://avatars.githubusercontent.com/u/95440233?  ...
# 4   https://avatars.githubusercontent.com/u/98070882?  ...
# 5   https://avatars.githubusercontent.com/u/41898282?  ...
# 6   https://avatars.githubusercontent.com/u/98070882?  ...
# 7   https://avatars.githubusercontent.com/u/38041391?  ...
# 8   https://avatars.githubusercontent.com/u/117162...  ...
# 9   https://avatars.githubusercontent.com/u/104618...  ...
# 10  https://avatars.githubusercontent.com/u/32935233?  ...
# 11  https://avatars.githubusercontent.com/u/82135647?  ...
# 12  https://avatars.githubusercontent.com/u/33859920?  ...
# 13  https://avatars.githubusercontent.com/u/29997978?  ...
# 14   https://avatars.githubusercontent.com/u/7370336?  ...
# 15  https://avatars.githubusercontent.com/u/41898282?  ...
# 16   https://avatars.githubusercontent.com/u/1155441?  ...
# 17  https://avatars.githubusercontent.com/u/16426260?  ...
# 18  https://avatars.githubusercontent.com/u/51714798?  ...
# 19  https://avatars.githubusercontent.com/u/41898282?  ...
# 20  https://avatars.githubusercontent.com/u/105747...  ...
# 21  https://avatars.githubusercontent.com/u/41898282?  ...
# 22  https://avatars.githubusercontent.com/u/49699333?  ...
# 23  https://avatars.githubusercontent.com/u/41898282?  ...
# 24   https://avatars.githubusercontent.com/u/1155441?  ...
# 25  https://avatars.githubusercontent.com/u/112394...  ...
# 26  https://avatars.githubusercontent.com/u/43733305?  ...
# 27  https://avatars.githubusercontent.com/u/41898282?  ...
# 28  https://avatars.githubusercontent.com/u/56889604?  ...
# 29  https://avatars.githubusercontent.com/u/41898282?  ...
#
#     payload.forkee.allow_forking payload.forkee.is_template  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# 5                            NaN                        NaN
# 6                            NaN                        NaN
# 7                            NaN                        NaN
# 8                            NaN                        NaN
# 9                            NaN                        NaN
# 10                           NaN                        NaN
# 11                           NaN                        NaN
# 12                           NaN                        NaN
# 13                           NaN                        NaN
# 14                           NaN                        NaN
# 15                           NaN                        NaN
# 16                           NaN                        NaN
# 17                           NaN                        NaN
# 18                           NaN                        NaN
# 19                           NaN                        NaN
# 20                           NaN                        NaN
# 21                           NaN                        NaN
# 22                           NaN                        NaN
# 23                           NaN                        NaN
# 24                           NaN                        NaN
# 25                           NaN                        NaN
# 26                           NaN                        NaN
# 27                           NaN                        NaN
# 28                          True                      False
# 29                           NaN                        NaN
#
#    payload.forkee.web_commit_signoff_required payload.forkee.topics  \
# 0                                         NaN                   NaN
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                         NaN                   NaN
# 5                                         NaN                   NaN
# 6                                         NaN                   NaN
# 7                                         NaN                   NaN
# 8                                         NaN                   NaN
# 9                                         NaN                   NaN
# 10                                        NaN                   NaN
# 11                                        NaN                   NaN
# 12                                        NaN                   NaN
# 13                                        NaN                   NaN
# 14                                        NaN                   NaN
# 15                                        NaN                   NaN
# 16                                        NaN                   NaN
# 17                                        NaN                   NaN
# 18                                        NaN                   NaN
# 19                                        NaN                   NaN
# 20                                        NaN                   NaN
# 21                                        NaN                   NaN
# 22                                        NaN                   NaN
# 23                                        NaN                   NaN
# 24                                        NaN                   NaN
# 25                                        NaN                   NaN
# 26                                        NaN                   NaN
# 27                                        NaN                   NaN
# 28                                      False                    []
# 29                                        NaN                   NaN
#
#    payload.forkee.visibility payload.forkee.forks payload.forkee.open_issues  \
# 0                        NaN                  NaN                        NaN
# 1                        NaN                  NaN                        NaN
# 2                        NaN                  NaN                        NaN
# 3                        NaN                  NaN                        NaN
# 4                        NaN                  NaN                        NaN
# 5                        NaN                  NaN                        NaN
# 6                        NaN                  NaN                        NaN
# 7                        NaN                  NaN                        NaN
# 8                        NaN                  NaN                        NaN
# 9                        NaN                  NaN                        NaN
# 10                       NaN                  NaN                        NaN
# 11                       NaN                  NaN                        NaN
# 12                       NaN                  NaN                        NaN
# 13                       NaN                  NaN                        NaN
# 14                       NaN                  NaN                        NaN
# 15                       NaN                  NaN                        NaN
# 16                       NaN                  NaN                        NaN
# 17                       NaN                  NaN                        NaN
# 18                       NaN                  NaN                        NaN
# 19                       NaN                  NaN                        NaN
# 20                       NaN                  NaN                        NaN
# 21                       NaN                  NaN                        NaN
# 22                       NaN                  NaN                        NaN
# 23                       NaN                  NaN                        NaN
# 24                       NaN                  NaN                        NaN
# 25                       NaN                  NaN                        NaN
# 26                       NaN                  NaN                        NaN
# 27                       NaN                  NaN                        NaN
# 28                    public                  0.0                        0.0
# 29                       NaN                  NaN                        NaN
#
#    payload.forkee.watchers payload.forkee.default_branch payload.forkee.public
# 0                      NaN                           NaN                   NaN
# 1                      NaN                           NaN                   NaN
# 2                      NaN                           NaN                   NaN
# 3                      NaN                           NaN                   NaN
# 4                      NaN                           NaN                   NaN
# 5                      NaN                           NaN                   NaN
# 6                      NaN                           NaN                   NaN
# 7                      NaN                           NaN                   NaN
# 8                      NaN                           NaN                   NaN
# 9                      NaN                           NaN                   NaN
# 10                     NaN                           NaN                   NaN
# 11                     NaN                           NaN                   NaN
# 12                     NaN                           NaN                   NaN
# 13                     NaN                           NaN                   NaN
# 14                     NaN                           NaN                   NaN
# 15                     NaN                           NaN                   NaN
# 16                     NaN                           NaN                   NaN
# 17                     NaN                           NaN                   NaN
# 18                     NaN                           NaN                   NaN
# 19                     NaN                           NaN                   NaN
# 20                     NaN                           NaN                   NaN
# 21                     NaN                           NaN                   NaN
# 22                     NaN                           NaN                   NaN
# 23                     NaN                           NaN                   NaN
# 24                     NaN                           NaN                   NaN
# 25                     NaN                           NaN                   NaN
# 26                     NaN                           NaN                   NaN
# 27                     NaN                           NaN                   NaN
# 28                     0.0                          main                  True
# 29                     NaN                           NaN                   NaN
#
# [30 rows x 551 columns]

# %% [markdown]
# #### Selecting only certain values by iterating with a for loop
#
# If we only want to select certain parts of the JSON:
# - Option 1: make a DataFrame and drop the rest.
# - Option 2: Use a for loop to extract only the required information.
#
# https://www.w3schools.com/python/python_for_loops.asp
#
# https://www.w3schools.com/python/ref_func_range.asp

# %%
# login - first value
github_response[0]['actor']['login']
# Out:
# 'Prash28'

# %%
# repo - first value
github_response[0]['repo']['name']
# Out:
# 'Prash28/C-'

# %%
# event_type - first value
github_response[0]['type']
# Out:
# 'CreateEvent'

# %%
# Empty lists that the loop will fill with values.
login = []
repo = []
event_type = []
repo_id = []

for i in range(len(github_response)):
    # add the ith login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the ith repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the ith event type to the event_type list
    event_type.append(github_response[i]['type'])
    repo_id.append(github_response[i]['repo']['id'])

# %%
repo_id
# Out:
# [560351309,
#  356331061,
#  559293948,
#  560352820,
#  458034268,
#  493805522,
#  457662221,
#  23992530,
#  560352816,
#  549212013,
#  333360371,
#  560346667,
#  559536070,
#  531442211,
#  371285039,
#  447965283,
#  560352813,
#  62607227,
#  543585776,
#  314055004,
#  560323187,
#  470356991,
#  431382886,
#  353600147,
#  560352813,
#  530188942,
#  183440182,
#  555465556,
#  560190457,
#  390217875]

# %%
# Let's have a look at the login list.
len(login)
# Out:
# 30

# %%
# Let's have a look at the repo list.
repo
# Out:
# ['Prash28/C-',
#  'torchmd/torchmd-net',
#  'Zqxg/Tasks',
#  'rialele/blood-bank-managment-system',
#  'seryozha1989/-5999455317753235474',
#  'gbuehler/CoverageJSON',
#  'seryozha1989/-477018030742834560',
#  'galaxyproject/tools-iuc',
#  'SmurfetteIs/Binary-Workflow-Pipeline',
#  'gablechain/gable',
#  'kjappelbaum/moffragmentor',
#  'xuhpppp/DrowsinessDetectionPython',
#  'H4de5-7/powershell-bypass',
#  'Luckynmc/test',
#  'equinor/fusion-framework',
#  'lb-lewisham/covid-dashboard',
#  'miickel/StyleGAN2',
#  'yangshun/tech-interview-handbook',
#  'agreeto/agreeto',
#  'bigwing/upptime',
#  'rajramk12/turboapp',
#  'jliew/silpostores',
#  'manny27416/docs',
#  'brocjad/pub_hofs',
#  'miickel/StyleGAN2',
#  'Daan071/Daan071.github.io',
#  'yanonono/booth-update',
#  'hvuddagi/ActionsTest',
#  'Workintech/FSWeb-S2G2-callback-ve-array',
#  'meganmackerwaler/banacle']

# %%
# Let's have a look at the event_type list.
event_type
# Out:
# ['CreateEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestReviewEvent',
#  'CreateEvent',
#  'PushEvent',
#  'IssuesEvent',
#  'CreateEvent',
#  'WatchEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'WatchEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'DeleteEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'IssuesEvent',
#  'ForkEvent',
#  'DeleteEvent']

# %% [markdown]
# ### International Space Station API - just another cool API
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'timestamp': 1667299261,
#  'message': 'success',
#  'iss_position': {'longitude': '164.4398', 'latitude': '-13.8034'}}

# %% [markdown]
# ## Spotipy

# %% [markdown]
# Now that you know all about APIs, let's use that knowledge on something even more fun.
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into a Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentication
#
# With most APIs we need to autheticate ourself. This is often done with a username and a password. You will likely use a different username and password for most APIs, so make sure you're using a password manager, or keep everything written down somewhere safe.
#
# If ever you'd like more information about spotipy: [here are the docs](https://spotipy.readthedocs.io/en/2.19.0/).

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    #client_id="82d10cbeab244ba885a29af43becd014",
    #client_secret="b23ecbf78eb743b38161dae226870f4c"))

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="4f3178f82dd54838a2e06c9d4003a726",
    client_secret="25b63863e2674da1a8a914ff62b53d04"))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This method allows you to find songs using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
# Search for 'Lady Gaga', restricted to the first 10 results.

results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
# Only one key makes it seem like there'll be many subdictionaries, let's delve deeper.
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
# You can play the track by pasting the url in your browser.

# We can explore further by adding keys one after the other.

results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: note the square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features contained in the search results:

# %%
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-tracks
# The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.

results["tracks"]["items"][0]["popularity"]
# Out:
# 82

# %% [markdown]
# This is how Spotify identifies individual songs: with a Uniform Resource Identifier  or `uri`. (The `id` and the `url` are also ways to identify each song uniquely).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chili Peppers and store the `uri` of the songs and their names.

# %%
# Send request and store the response.
red_hot = sp.search(q="Red Hot Chili Peppers", limit=10)

# Initialize empty lists that we will fill with information from our loop.
list_of_uri = []
list_of_song_names = []

# Iterate through the "items" (the songs),
# and append the "uri" and the "name" to the lists we created.
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# Print results.
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg', 'spotify:track:1f2V8U1BiWaC9aJWmpOARe', 'spotify:track:64BbK9SFKH2jk86U3dGj2P', 'spotify:track:1G391cbiT3v3Cywg8T7DM1', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:3a94TbZOxhkI9xuNwYL53b']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Californication', "Can't Stop", 'Pedigree', 'By the Way', 'Otherside', 'Scar Tissue', 'Buried Alive', 'Black Summer']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results to a big list called `results`.

# %%
artists = ["Red Hot Chili Peppers", "SCARR", "Whitney Houston", "Sepultura"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
# Let's look at the second element in the results list.
results[3]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Sepultura&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JjnPCfpp6redrkKpXZAs8'},
#      'href': 'https://api.spotify.com/v1/albums/5JjnPCfpp6redrkKpXZAs8',
#      'id': '5JjnPCfpp6redrkKpXZAs8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730bd5e7cce9765c2ef519424e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020bd5e7cce9765c2ef519424e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510bd5e7cce9765c2ef519424e',
#        'width': 64}],
#      'name': 'Roots',
#      'release_date': '1996-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5JjnPCfpp6redrkKpXZAs8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 212253,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329513650'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ursmCnbc9oDRGa2yHKkoZ'},
#     'href': 'https://api.spotify.com/v1/tracks/6ursmCnbc9oDRGa2yHKkoZ',
#     'id': '6ursmCnbc9oDRGa2yHKkoZ',
#     'is_local': False,
#     'name': 'Roots Bloody Roots',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1398a86f361a5d10dda282f591f661be913c105?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ursmCnbc9oDRGa2yHKkoZ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ercY0q4h165z8LS72ulrW'},
#        'href': 'https://api.spotify.com/v1/artists/5ercY0q4h165z8LS72ulrW',
#        'id': '5ercY0q4h165z8LS72ulrW',
#        'name': 'Tay Łore',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ercY0q4h165z8LS72ulrW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6SfbsxJvYn6yTOi278VZLX'},
#      'href': 'https://api.spotify.com/v1/albums/6SfbsxJvYn6yTOi278VZLX',
#      'id': '6SfbsxJvYn6yTOi278VZLX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d98fd4e69287712cbe4324c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d98fd4e69287712cbe4324c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d98fd4e69287712cbe4324c7',
#        'width': 64}],
#      'name': 'Sepultura',
#      'release_date': '2022-10-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6SfbsxJvYn6yTOi278VZLX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ercY0q4h165z8LS72ulrW'},
#       'href': 'https://api.spotify.com/v1/artists/5ercY0q4h165z8LS72ulrW',
#       'id': '5ercY0q4h165z8LS72ulrW',
#       'name': 'Tay Łore',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ercY0q4h165z8LS72ulrW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 127500,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZPLS2250713'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15YPflJ4WPjP6lZbUpVdBy'},
#     'href': 'https://api.spotify.com/v1/tracks/15YPflJ4WPjP6lZbUpVdBy',
#     'id': '15YPflJ4WPjP6lZbUpVdBy',
#     'is_local': False,
#     'name': 'Sepultura',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/339e583e76ebe76855507fea201af09bab33a057?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:15YPflJ4WPjP6lZbUpVdBy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AL',
#       'AM',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BE',
#       'BG',
#       'BY',
#       'CA',
#       'CH',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GE',
#       'GR',
#       'HR',
#       'HU',
#       'IE',
#       'IS',
#       'IT',
#       'KI',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MT',
#       'NL',
#       'NO',
#       'NR',
#       'NZ',
#       'PG',
#       'PL',
#       'PT',
#       'RO',
#       'RS',
#       'SB',
#       'SE',
#       'SI',
#       'SK',
#       'SM',
#       'TO',
#       'TR',
#       'TV',
#       'UA',
#       'US',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1zZ2mFxHHq3JRtW6Mzuhht'},
#      'href': 'https://api.spotify.com/v1/albums/1zZ2mFxHHq3JRtW6Mzuhht',
#      'id': '1zZ2mFxHHq3JRtW6Mzuhht',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e45315590609aff23517aa3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e45315590609aff23517aa3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e45315590609aff23517aa3',
#        'width': 64}],
#      'name': 'Kairos',
#      'release_date': '2011-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1zZ2mFxHHq3JRtW6Mzuhht'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AL',
#      'AM',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BE',
#      'BG',
#      'BY',
#      'CA',
#      'CH',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GE',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IS',
#      'IT',
#      'KI',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MH',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'PG',
#      'PL',
#      'PT',
#      'RO',
#      'RS',
#      'SB',
#      'SE',
#      'SI',
#      'SK',
#      'SM',
#      'TO',
#      'TR',
#      'TV',
#      'UA',
#      'US',
#      'VU',
#      'WS',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 210200,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED831100254'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4P3pRa8uFRJo4Vo8DSwDvB'},
#     'href': 'https://api.spotify.com/v1/tracks/4P3pRa8uFRJo4Vo8DSwDvB',
#     'id': '4P3pRa8uFRJo4Vo8DSwDvB',
#     'is_local': False,
#     'name': 'Just One Fix',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9c2027b8d1574a2e7c3343f09b7142944ed8e99b?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4P3pRa8uFRJo4Vo8DSwDvB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5r4qa5AIQUVypFRXQzjaiu'},
#      'href': 'https://api.spotify.com/v1/albums/5r4qa5AIQUVypFRXQzjaiu',
#      'id': '5r4qa5AIQUVypFRXQzjaiu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c0b2d74cfb910735ca55317',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c0b2d74cfb910735ca55317',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c0b2d74cfb910735ca55317',
#        'width': 64}],
#      'name': 'Chaos A.D.',
#      'release_date': '1993-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5r4qa5AIQUVypFRXQzjaiu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 287480,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329301560'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0QRxtcxL31dRAeiUUuENPu'},
#     'href': 'https://api.spotify.com/v1/tracks/0QRxtcxL31dRAeiUUuENPu',
#     'id': '0QRxtcxL31dRAeiUUuENPu',
#     'is_local': False,
#     'name': 'Territory',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8614b815c528f1787eb9ced01d80825df9bf7283?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0QRxtcxL31dRAeiUUuENPu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5r4qa5AIQUVypFRXQzjaiu'},
#      'href': 'https://api.spotify.com/v1/albums/5r4qa5AIQUVypFRXQzjaiu',
#      'id': '5r4qa5AIQUVypFRXQzjaiu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c0b2d74cfb910735ca55317',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c0b2d74cfb910735ca55317',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c0b2d74cfb910735ca55317',
#        'width': 64}],
#      'name': 'Chaos A.D.',
#      'release_date': '1993-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5r4qa5AIQUVypFRXQzjaiu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 199226,
#     'explicit': True,
#     'external_ids': {'isrc': 'NLA329301550'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2OoS1aZFAFscH1cUiKlazH'},
#     'href': 'https://api.spotify.com/v1/tracks/2OoS1aZFAFscH1cUiKlazH',
#     'id': '2OoS1aZFAFscH1cUiKlazH',
#     'is_local': False,
#     'name': 'Refuse / Resist',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1f8f4c0194b0ffb6aadef2ee74a7efc2fae46f54?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2OoS1aZFAFscH1cUiKlazH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3BDZvMYxZ6E8IuSQL2ew6Z'},
#      'href': 'https://api.spotify.com/v1/albums/3BDZvMYxZ6E8IuSQL2ew6Z',
#      'id': '3BDZvMYxZ6E8IuSQL2ew6Z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27317db2369086bf97cbe5e44b1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0217db2369086bf97cbe5e44b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485117db2369086bf97cbe5e44b1',
#        'width': 64}],
#      'name': 'Beneath the Remains',
#      'release_date': '1989-04-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3BDZvMYxZ6E8IuSQL2ew6Z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 314160,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329780625'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dY6SLslpYq09BKeZxzVCC'},
#     'href': 'https://api.spotify.com/v1/tracks/3dY6SLslpYq09BKeZxzVCC',
#     'id': '3dY6SLslpYq09BKeZxzVCC',
#     'is_local': False,
#     'name': 'Beneath the Remains',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/badd8802c24a80d36a1f107f526a8f8588f17c09?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3dY6SLslpYq09BKeZxzVCC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LFLROOEJvxtDPlSqinvKz'},
#        'href': 'https://api.spotify.com/v1/artists/3LFLROOEJvxtDPlSqinvKz',
#        'id': '3LFLROOEJvxtDPlSqinvKz',
#        'name': 'CROKO LOOKO',
#        'type': 'artist',
#        'uri': 'spotify:artist:3LFLROOEJvxtDPlSqinvKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6eEjv7gtsnnYOWcbT55xKz'},
#      'href': 'https://api.spotify.com/v1/albums/6eEjv7gtsnnYOWcbT55xKz',
#      'id': '6eEjv7gtsnnYOWcbT55xKz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27373add371aa6f560d586f097f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0273add371aa6f560d586f097f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485173add371aa6f560d586f097f',
#        'width': 64}],
#      'name': 'Despertar',
#      'release_date': '2021-12-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6eEjv7gtsnnYOWcbT55xKz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LFLROOEJvxtDPlSqinvKz'},
#       'href': 'https://api.spotify.com/v1/artists/3LFLROOEJvxtDPlSqinvKz',
#       'id': '3LFLROOEJvxtDPlSqinvKz',
#       'name': 'CROKO LOOKO',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LFLROOEJvxtDPlSqinvKz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 125624,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA2M2110515'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18AmWjCc6k9EqCZam3jpcx'},
#     'href': 'https://api.spotify.com/v1/tracks/18AmWjCc6k9EqCZam3jpcx',
#     'id': '18AmWjCc6k9EqCZam3jpcx',
#     'is_local': False,
#     'name': 'Sepultura',
#     'popularity': 10,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f1bb70e27da271eed05c29b926815ea0e6b8512d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:18AmWjCc6k9EqCZam3jpcx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7hgWmH16eu70yqrg5Pc3SM'},
#      'href': 'https://api.spotify.com/v1/albums/7hgWmH16eu70yqrg5Pc3SM',
#      'id': '7hgWmH16eu70yqrg5Pc3SM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736ee5427674e1b32a79f7567a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026ee5427674e1b32a79f7567a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516ee5427674e1b32a79f7567a',
#        'width': 64}],
#      'name': 'Arise',
#      'release_date': '1991-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7hgWmH16eu70yqrg5Pc3SM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 198226,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329780651'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1erRDf98WX0VllciGPYO1H'},
#     'href': 'https://api.spotify.com/v1/tracks/1erRDf98WX0VllciGPYO1H',
#     'id': '1erRDf98WX0VllciGPYO1H',
#     'is_local': False,
#     'name': 'Arise',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/44093733c97970414f386f4fee1a69dd1f92592d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1erRDf98WX0VllciGPYO1H'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JjnPCfpp6redrkKpXZAs8'},
#      'href': 'https://api.spotify.com/v1/albums/5JjnPCfpp6redrkKpXZAs8',
#      'id': '5JjnPCfpp6redrkKpXZAs8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730bd5e7cce9765c2ef519424e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020bd5e7cce9765c2ef519424e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510bd5e7cce9765c2ef519424e',
#        'width': 64}],
#      'name': 'Roots',
#      'release_date': '1996-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5JjnPCfpp6redrkKpXZAs8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 270640,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329513680'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Tg8JctqoeIwZ3Rue8BjaI'},
#     'href': 'https://api.spotify.com/v1/tracks/3Tg8JctqoeIwZ3Rue8BjaI',
#     'id': '3Tg8JctqoeIwZ3Rue8BjaI',
#     'is_local': False,
#     'name': 'Ratamahatta',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab7886471d52f40941f3572d17c3a438d5ca61ab?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3Tg8JctqoeIwZ3Rue8BjaI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#        'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#        'id': '6JW8wliOEwaDZ231ZY7cf4',
#        'name': 'Sepultura',
#        'type': 'artist',
#        'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5r4qa5AIQUVypFRXQzjaiu'},
#      'href': 'https://api.spotify.com/v1/albums/5r4qa5AIQUVypFRXQzjaiu',
#      'id': '5r4qa5AIQUVypFRXQzjaiu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c0b2d74cfb910735ca55317',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c0b2d74cfb910735ca55317',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c0b2d74cfb910735ca55317',
#        'width': 64}],
#      'name': 'Chaos A.D.',
#      'release_date': '1993-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5r4qa5AIQUVypFRXQzjaiu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6JW8wliOEwaDZ231ZY7cf4'},
#       'href': 'https://api.spotify.com/v1/artists/6JW8wliOEwaDZ231ZY7cf4',
#       'id': '6JW8wliOEwaDZ231ZY7cf4',
#       'name': 'Sepultura',
#       'type': 'artist',
#       'uri': 'spotify:artist:6JW8wliOEwaDZ231ZY7cf4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 299120,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA329301650'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3MYhRTonhQATwN9gO7RsJL'},
#     'href': 'https://api.spotify.com/v1/tracks/3MYhRTonhQATwN9gO7RsJL',
#     'id': '3MYhRTonhQATwN9gO7RsJL',
#     'is_local': False,
#     'name': 'Nomad',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ae0c3dcd02891a29bc78e33ba23c6c4d6c77a199?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3MYhRTonhQATwN9gO7RsJL'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Sepultura&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1161}}

# %% [markdown]
# We can iterate through the `results` list and get just the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Californication',
#  "Can't Stop",
#  'Pedigree',
#  'By the Way',
#  'Otherside',
#  'Scar Tissue',
#  'Buried Alive',
#  'Black Summer',
#  'Scarred',
#  'Emotionally Scarred',
#  'Scary Garry',
#  'Scarred From Love',
#  'SCARR',
#  'Scarred',
#  'Vert (feat. Big Scarr)',
#  'MJ (feat. Quezz Ruthless)',
#  "Scarred Baby's",
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'Higher Love',
#  'I Have Nothing',
#  'How Will I Know',
#  'I Will Always Love You',
#  'Greatest Love of All',
#  'How Will I Know',
#  'You Give Good Love',
#  'Saving All My Love for You',
#  'I Wanna Dance with Somebody (Who Loves Me) - David Solomon Remix',
#  'Roots Bloody Roots',
#  'Sepultura',
#  'Just One Fix',
#  'Territory',
#  'Refuse / Resist',
#  'Beneath the Remains',
#  'Sepultura',
#  'Arise',
#  'Ratamahatta',
#  'Nomad']

# %% [markdown]
# ### Playlists
#
# Using spotipy, we can both build and read spotify playlists. Today, we will only show you how to read information from a playlist. However, if you wish to build one, we strongly encourage you read the [documentation](https://spotipy.readthedocs.io/en/2.19.0/) and explore further.

# %%
my_playlist = sp.user_playlist_tracks(user="spotify", playlist_id="spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8")

# %% [markdown]
# Extract songs ID from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0ce6Rmxf7QXroqa1wzjWY8/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-22T07:34:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#        'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#        'id': '579T5fNgfbDetyamUTAetw',
#        'name': 'S+C+A+R+R',
#        'type': 'artist',
#        'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#      'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#      'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#        'width': 64}],
#      'name': 'You\'re the One (From "I Lost My Body")',
#      'release_date': '2019-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 167986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6F31902770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#     'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#     'id': '5Tnx4R7Gwj1LZsfssfzchh',
#     'is_local': False,
#     'name': 'You\'re the One - From "I Lost My Body"',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d42e003a7ba7293394d75af67584659dccce2012?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#        'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#        'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#        'name': 'Manchester Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#      'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#      'id': '4hruYceqit29o6m4arpAql',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#        'width': 64}],
#      'name': 'A Black Mile To The Surface',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 328933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1702133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#     'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#     'is_local': False,
#     'name': 'The Alien',
#     'popularity': 46,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#        'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#        'id': '1rqPrJjVzB01kfoQpz6XNe',
#        'name': 'Nina & Frederik',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#      'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#      'id': '63obBSI5HlMFoawrrq8RDG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#        'width': 64}],
#      'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#      'release_date': '1958-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#       'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#       'id': '1rqPrJjVzB01kfoQpz6XNe',
#       'name': 'Nina & Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 145773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560979249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#     'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#     'id': '0R3OcHrzq3f8raukyZgTAc',
#     'is_local': False,
#     'name': 'Oh, Pecador (Oh, Sinne Man)',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d8ad67f1e113b024d90188a0015d7f53131efc9d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#        'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#        'id': '2G7QgTep5IsJHGHm1hXygD',
#        'name': 'Kid Francescoli',
#        'type': 'artist',
#        'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#      'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#      'id': '4iII9nfzjxOYQFp8PyV6HD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#        'width': 64}],
#      'name': 'Play Me Again',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63fbQTZ9yW3SUsBRYcn1Wm'},
#       'href': 'https://api.spotify.com/v1/artists/63fbQTZ9yW3SUsBRYcn1Wm',
#       'id': '63fbQTZ9yW3SUsBRYcn1Wm',
#       'name': 'Julia Minkin',
#       'type': 'artist',
#       'uri': 'spotify:artist:63fbQTZ9yW3SUsBRYcn1Wm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 390638,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRP621600280'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#     'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#     'id': '24upABZ8A0sAepfu91sEYr',
#     'is_local': False,
#     'name': 'Moon (And It Went Like)',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbdc77c2fad05ac37a494bc2976e4fed73a018f2?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#        'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#        'id': '4aEnNH9PuU1HF3TsZTru54',
#        'name': 'Caribou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#      'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#      'id': '1NqhnYAVqlHuPG2OlgKSZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#        'width': 64}],
#      'name': 'Never Come Back',
#      'release_date': '2020-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 305480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED622000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#     'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#     'id': '7IBrKDuBlyz3vW9JFCux10',
#     'is_local': False,
#     'name': 'Never Come Back',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#        'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#        'id': '6wH6iStAh4KIaWfuhf0NYM',
#        'name': 'Manu Chao',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#      'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#      'id': '6sLpbLsD1LlXnlCRjt8YuE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#        'width': 64}],
#      'name': 'Proxima Estacion : Esperanza',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 114920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR84R0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#     'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#     'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#     'is_local': False,
#     'name': 'Trapped By Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:50:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#        'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#        'id': '5v74mT11KGJqadf9sLw4dA',
#        'name': 'Cannonball Adderley',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#      'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#      'id': '5JpHin9lKOyizuJhKxaHWp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#        'width': 64}],
#      'name': 'Jazz Profile: Cannonball Adderley',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 313200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29000136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#     'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#     'id': '6NF8MZ2trxckVBr82pyyPt',
#     'is_local': False,
#     'name': 'Mercy, Mercy, Mercy',
#     'popularity': 54,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#        'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#        'id': '3ayds6VIVBx3CU5NSNCDbq',
#        'name': 'Jacques Dutronc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#      'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#      'id': '2S4mgB4hHSszPRGoYrGJ0d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#        'width': 64}],
#      'name': "L' aventurier",
#      'release_date': '1969-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 155600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ196900030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#     'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#     'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#     'is_local': False,
#     'name': 'Le responsable',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1ec3eeb9336b36e7a568a4c0f9b8dc67d2e49280?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#        'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#        'id': '2AR42Ur9PcchQDtEdwkv4L',
#        'name': 'Floating Points',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
# ...
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2adSO4KU3FDjeM1PXCRDZm'},
#      'href': 'https://api.spotify.com/v1/albums/2adSO4KU3FDjeM1PXCRDZm',
#      'id': '2adSO4KU3FDjeM1PXCRDZm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f461bbc21a9bcec43a926973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f461bbc21a9bcec43a926973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f461bbc21a9bcec43a926973',
#        'width': 64}],
#      'name': 'The Business',
#      'release_date': '2020-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2adSO4KU3FDjeM1PXCRDZm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 164000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA112000624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6f3Slt0GbA2bPZlz0aIFXN'},
#     'href': 'https://api.spotify.com/v1/tracks/6f3Slt0GbA2bPZlz0aIFXN',
#     'id': '6f3Slt0GbA2bPZlz0aIFXN',
#     'is_local': False,
#     'name': 'The Business',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0eab33c8cf88fdd3046bd58133b6cbf2fe31773c?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6f3Slt0GbA2bPZlz0aIFXN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/not_invented_here'},
#     'href': 'https://api.spotify.com/v1/users/not_invented_here',
#     'id': 'not_invented_here',
#     'type': 'user',
#     'uri': 'spotify:user:not_invented_here'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#        'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#        'id': '7qmf5YAQYjfjBF9C7kkjzs',
#        'name': 'Johnny Hooker',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#      'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#      'id': '0kelpiZssyYlVNks8cHEth',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#        'width': 64}],
#      'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#      'release_date': '2015-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#       'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#       'id': '7qmf5YAQYjfjBF9C7kkjzs',
#       'name': 'Johnny Hooker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 285000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh1563538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#     'id': '7uSdpAkxgB0948bW7yjjJO',
#     'is_local': False,
#     'name': 'Amor Marginal',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#     'href': 'https://api.spotify.com/v1/users/shokoshock',
#     'id': 'shokoshock',
#     'type': 'user',
#     'uri': 'spotify:user:shokoshock'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#        'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#        'id': '0YMeriqrS3zgsX24nfY0F0',
#        'name': 'The Tragically Hip',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#      'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#      'id': '6fRGXiRnTyLLRDXpXkrK1n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#        'width': 64}],
#      'name': 'Yer Favourites',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 225426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM199600015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#     'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#     'id': '5nC2BQzszGGkZi7cvxFzH4',
#     'is_local': False,
#     'name': 'Ahead By A Century',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T13:02:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#     'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#     'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#     'type': 'user',
#     'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#        'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#        'id': '7zsin6IgVsR1rqSRCNYDwq',
#        'name': 'Family of the Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#      'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#      'id': '14SCnv027L0HidHq0URIDu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#        'width': 64}],
#      'name': 'Loma Vista',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111200237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#     'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#     'id': '6GRDI9suQHikFP6euIXnpq',
#     'is_local': False,
#     'name': 'Hero',
#     'popularity': 2,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-29T14:22:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#     'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#     'id': '8em1nqrnfspx3alyw0rz3ggn1',
#     'type': 'user',
#     'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#        'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#        'id': '58r1rB5t3VF5X6yXGPequV',
#        'name': 'Maverick City Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#      'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#      'id': '0prxUuXzlIyjSJU9ej003n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#        'width': 64}],
#      'name': 'Maverick City Vol. 3 Part 1',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#       'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#       'id': '5nO7Yt0Jon48sqKR6VME4T',
#       'name': 'Joe L Barnes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#       'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#       'id': '4rc8nzClXj7sUjvsHVg6AD',
#       'name': 'Naomi Raine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 646239,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2042835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#     'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#     'id': '0aZFEiDKLK2B4gzPaGCZVm',
#     'is_local': False,
#     'name': 'Promises',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 16}

# %%
my_playlist["items"][0]["track"]["album"].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'

# %% [markdown]
# ### Audio features
#
# You can check an explanation of the audio features [here](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/).

# %%
sp.audio_features("spotify:track:6Sy9BUbgFse0n0LPA5lwy5")
# Out:
# [{'danceability': 0.528,
#   'energy': 0.965,
#   'key': 11,
#   'loudness': -7.984,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.141,
#   'instrumentalness': 0.985,
#   'liveness': 0.0797,
#   'valence': 0.587,
#   'tempo': 136.065,
#   'type': 'audio_features',
#   'id': '6Sy9BUbgFse0n0LPA5lwy5',
#   'uri': 'spotify:track:6Sy9BUbgFse0n0LPA5lwy5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sy9BUbgFse0n0LPA5lwy5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sy9BUbgFse0n0LPA5lwy5',
#   'duration_ms': 225493,
#   'time_signature': 4}]

# %% [markdown]
# ### Creating a function that takes a song name and returns its audio features

# %%
def song_features(human_song_title):
    list_of_songs = []
    # Search for the song title you enter into the function, limited to the first 10 results.
    results = sp.search(q=human_song_title, limit = 10)['tracks']['items']
    
    # Create a loop, so we only select the parts of the json we need.
    for result in results:

        # Empty dictionary to be filled with the information below.
        track_dict = {}

        # Add the key artist and a corresponding value to the dictionary.
        track_dict['Artist'] = result['artists'][0]['name']
        # Add the key title and the corresponding value to the dictionary.
        track_dict['Title'] = result['name'] 
        # Add the key album and the corresponding value to the dictionary.
        track_dict['Album'] = result['album']['name']
        # Add the key audio description and the corresponding value to the dictionary.
        track_dict['Audio Description'] = sp.audio_features(result['id'])
        
        # Add the dictionary to the list list_of_songs.
        list_of_songs.append(track_dict)
    # Output list_of_songs.
    return list_of_songs

# %%
# Call the function with a song to test.
songs = song_features("Under the Bridge")

# %%
# Make a dataframe from the list of songs created in the function above.
df = pd.DataFrame(songs)

df
# Out:
#                   Artist                                 Title  \
# 0  Red Hot Chili Peppers                      Under the Bridge
# 1                   owlh                      Under the Bridge
# 2                  Adele                Water Under the Bridge
# 3                Santana  Under the Bridge (feat. Andy Vargas)
# 4  Red Hot Chili Peppers                      Under the Bridge
# 5         Rockabye Baby!                      Under the Bridge
# 6               Sam Hunt                Water Under The Bridge
# 7            Lance Allen                      Under the Bridge
# 8            Jack Harlow         Churchill Downs (feat. Drake)
# 9             All Saints                      Under the Bridge
#
#                                                Album  \
# 0             Blood Sugar Sex Magik (Deluxe Edition)
# 1                                     cover to cover
# 2                                                 25
# 3  Guitar Heaven: The Greatest Guitar Classics Of...
# 4                                      Greatest Hits
# 5        Lullaby Renditions of Red Hot Chili Peppers
# 6                             Water Under The Bridge
# 7                                   Under the Bridge
# 8                        Come Home The Kids Miss You
# 9                                         All Saints
#
#                                    Audio Description
# 0  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 1  [{'danceability': 0.781, 'energy': 0.355, 'key...
# 2  [{'danceability': 0.59, 'energy': 0.833, 'key'...
# 3  [{'danceability': 0.54, 'energy': 0.844, 'key'...
# 4  [{'danceability': 0.554, 'energy': 0.49, 'key'...
# 5  [{'danceability': 0.704, 'energy': 0.06, 'key'...
# 6  [{'danceability': 0.635, 'energy': 0.866, 'key...
# 7  [{'danceability': 0.538, 'energy': 0.24, 'key'...
# 8  [{'danceability': 0.71, 'energy': 0.522, 'key'...
# 9  [{'danceability': 0.717, 'energy': 0.564, 'key...

# %% [markdown]
# As you can see, this DataFrame looks a bit off as the audio descriptions aren't expanded - all of the data is clumped together in one cell. Let's correct this, so we can see each audio feature as an individual column.

# %%
# Quick function we can use to select only the first item.
# This can also be done simply with [0], but we wanted to show you how you can incorporate a custom function into your work.

def first_value (x):
    return x[0]

# Making a DataFrame from the audio features of the songs in list_of_songs.
df_audio_features = pd.json_normalize(df['Audio Description'].apply(first_value))

df_audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.559   0.345    4   -13.496     1       0.0459        0.0576
# 1         0.781   0.355    9    -8.158     1       0.0376        0.4710
# 2         0.590   0.833    5    -6.503     0       0.0615        0.0142
# 3         0.540   0.844    1    -4.986     0       0.0871        0.2710
# 4         0.554   0.490    4    -8.046     1       0.0457        0.0168
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000105     0.141    0.458   84.581  audio_features
# 1          0.878000     0.125    0.363  131.978  audio_features
# 2          0.000005     0.105    0.538   94.963  audio_features
# 3          0.000009     0.155    0.644   87.518  audio_features
# 4          0.000534     0.136    0.513   84.275  audio_features
#
#                        id                                   uri  \
# 0  3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  1AyRpRvLwUwkXwGGuNZHmN  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  4jL6WWKFDqCOPo2hC3VhSS  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  1AK5AYYFRCnd6qKrmh1N5t  spotify:track:1AK5AYYFRCnd6qKrmh1N5t
# 4  23NPGXlSaIqWzvxIRhM2oG  spotify:track:23NPGXlSaIqWzvxIRhM2oG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/1AK5AYYFRCnd...
# 4  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...       244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...       240439
# 3  https://api.spotify.com/v1/audio-analysis/1AK5...       309547
# 4  https://api.spotify.com/v1/audio-analysis/23NP...       265507
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
df.head(2)
# Out:
#                   Artist             Title  \
# 0  Red Hot Chili Peppers  Under the Bridge
# 1                   owlh  Under the Bridge
#
#                                     Album  \
# 0  Blood Sugar Sex Magik (Deluxe Edition)
# 1                          cover to cover
#
#                                    Audio Description
# 0  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 1  [{'danceability': 0.781, 'energy': 0.355, 'key...

# %%
# Merge the expanded audio features with the original DataFrame.
new_df = pd.merge(df, df_audio_features, left_index=True, right_index=True)

# Drop the old ugly column where all the audio features are clumped together.
new_df.drop('Audio Description', axis=1, inplace=True)

new_df
# Out:
#                   Artist                                 Title  \
# 0  Red Hot Chili Peppers                      Under the Bridge
# 1                   owlh                      Under the Bridge
# 2                  Adele                Water Under the Bridge
# 3                Santana  Under the Bridge (feat. Andy Vargas)
# 4  Red Hot Chili Peppers                      Under the Bridge
# 5         Rockabye Baby!                      Under the Bridge
# 6               Sam Hunt                Water Under The Bridge
# 7            Lance Allen                      Under the Bridge
# 8            Jack Harlow         Churchill Downs (feat. Drake)
# 9             All Saints                      Under the Bridge
#
#                                                Album  danceability  energy  \
# 0             Blood Sugar Sex Magik (Deluxe Edition)         0.559   0.345
# 1                                     cover to cover         0.781   0.355
# 2                                                 25         0.590   0.833
# 3  Guitar Heaven: The Greatest Guitar Classics Of...         0.540   0.844
# 4                                      Greatest Hits         0.554   0.490
# 5        Lullaby Renditions of Red Hot Chili Peppers         0.704   0.060
# 6                             Water Under The Bridge         0.635   0.866
# 7                                   Under the Bridge         0.538   0.240
# 8                        Come Home The Kids Miss You         0.710   0.522
# 9                                         All Saints         0.717   0.564
#
#    key  loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0    4   -13.496     1       0.0459        0.0576  ...    0.1410    0.458
# 1    9    -8.158     1       0.0376        0.4710  ...    0.1250    0.363
# 2    5    -6.503     0       0.0615        0.0142  ...    0.1050    0.538
# 3    1    -4.986     0       0.0871        0.2710  ...    0.1550    0.644
# 4    4    -8.046     1       0.0457        0.0168  ...    0.1360    0.513
# 5    4   -21.087     1       0.0907        0.9460  ...    0.1090    0.791
# 6    5    -2.695     1       0.0473        0.0697  ...    0.0955    0.853
# 7    4   -14.321     1       0.0580        0.9110  ...    0.1220    0.395
# 8   11    -9.102     1       0.3600        0.6150  ...    0.1100    0.370
# 9    6    -7.752     0       0.0551        0.0452  ...    0.0897    0.728
#
#      tempo            type                      id  \
# 0   84.581  audio_features  3d9DChrdc6BOeFsbrZ3Is0
# 1  131.978  audio_features  1AyRpRvLwUwkXwGGuNZHmN
# 2   94.963  audio_features  4jL6WWKFDqCOPo2hC3VhSS
# 3   87.518  audio_features  1AK5AYYFRCnd6qKrmh1N5t
# 4   84.275  audio_features  23NPGXlSaIqWzvxIRhM2oG
# 5  158.085  audio_features  45VCZtguiCNu5zJ3YkmcWC
# 6  133.889  audio_features  4viFAHmivkYQKkwLvwKOgg
# 7   78.196  audio_features  4gGkOirjuBwPUd0OI00p1I
# 8   96.448  audio_features  3EMp20j5E42MxfFbsEsIvD
# 9   85.996  audio_features  78M2x5ojbdTmUOpWrbijG3
#
#                                     uri  \
# 0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  spotify:track:1AK5AYYFRCnd6qKrmh1N5t
# 4  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 5  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 6  spotify:track:4viFAHmivkYQKkwLvwKOgg
# 7  spotify:track:4gGkOirjuBwPUd0OI00p1I
# 8  spotify:track:3EMp20j5E42MxfFbsEsIvD
# 9  spotify:track:78M2x5ojbdTmUOpWrbijG3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/1AK5AYYFRCnd...
# 4  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 5  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 6  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
# 7  https://api.spotify.com/v1/tracks/4gGkOirjuBwP...
# 8  https://api.spotify.com/v1/tracks/3EMp20j5E42M...
# 9  https://api.spotify.com/v1/tracks/78M2x5ojbdTm...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...      264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...      244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...      240439
# 3  https://api.spotify.com/v1/audio-analysis/1AK5...      309547
# 4  https://api.spotify.com/v1/audio-analysis/23NP...      265507
# 5  https://api.spotify.com/v1/audio-analysis/45VC...      259693
# 6  https://api.spotify.com/v1/audio-analysis/4viF...      169760
# 7  https://api.spotify.com/v1/audio-analysis/4gGk...      183202
# 8  https://api.spotify.com/v1/audio-analysis/3EMp...      309327
# 9  https://api.spotify.com/v1/audio-analysis/78M2...      301067
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
#
# [10 rows x 21 columns]

# %% [markdown]
# If you like a challenge and want to have a go at testing what you've just learned: Follow the steps below and see if you can make a DataFrame similar to the one above with expanded audio features. This time though, do it for a playlist of your choice on spotify. Then see if you can expand it to include the songs from multiple playlists.
#
# Try not to look at the solution, but we've included it below in case you get stuck
#
# ### Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have to be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
# your code here

# %% [markdown]
# #### Solution

# %%
list_of_playlists = ["spotify:playlist:2zjepkjZxLpeIBlvPCWIHl",
                    "spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8"]

track_list = []
for i in list_of_playlists:
    individual_playlist = sp.user_playlist_tracks(user="spotify", playlist_id=i)['items']
    for j in individual_playlist:
        track_dict = {}
        track_dict['Artist'] = j['track']['artists'][0]['name']
        track_dict['Title'] = j['track']['name']
        track_dict['Album'] = j['track']['album']['name']
        track_dict['Audio Description'] = sp.audio_features(j['track']['id'])
        track_list.append(track_dict)

print(track_list)

# %%
playlist_df = pd.DataFrame(track_list)

# %%
df_a_f = pd.json_normalize(playlist_df['Audio Description'].apply(first_value))

# %%
new_playlist_df = pd.merge(playlist_df, df_a_f, left_index=True, right_index=True)

# %%
new_playlist_df.drop('Audio Description', axis=1, inplace=True)

# %%
new_playlist_df
