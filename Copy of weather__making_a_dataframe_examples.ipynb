# %% [markdown]
# We've included 2 solutions here. There are also many other ways of formatting this data. Don't wory if you haven't done it exactly like we have.... this is just guide and not a bible.

# %%
import pandas as pd
import requests
from datetime import datetime
import pytz

# %% [markdown]
# # Solution using a for loop

# %% [markdown]
# First we need to take a look at the JSON so we know what we're dealing with.
# - We can view what the JSON contains by checking out the [documentation on the OWM website](https://openweathermap.org/forecast5)
# - Or this can be done manually, like below:

# %%
city = 'Berlin'
API_key = '7c94895786f3d0292d6248ccfd58881e'

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")

response = requests.get(url)
json = response.json()

json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1667412000,
#    'main': {'temp': 13.5,
#     'feels_like': 12.45,
#     'temp_min': 11.82,
#     'temp_max': 13.5,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1015,
#     'humidity': 59,
#     'temp_kf': 1.68},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.86, 'deg': 254, 'gust': 9.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-02 18:00:00'},
#   {'dt': 1667422800,
#    'main': {'temp': 11.52,
#     'feels_like': 10.42,
#     'temp_min': 10.11,
#     'temp_max': 11.52,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 65,
#     'temp_kf': 1.41},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.12, 'deg': 242, 'gust': 8.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-02 21:00:00'},
#   {'dt': 1667433600,
#    'main': {'temp': 9.34,
#     'feels_like': 8.21,
#     'temp_min': 9.34,
#     'temp_max': 9.34,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 2.27, 'deg': 188, 'gust': 4.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-03 00:00:00'},
#   {'dt': 1667444400,
#    'main': {'temp': 8.61,
#     'feels_like': 6.77,
#     'temp_min': 8.61,
#     'temp_max': 8.61,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 3.12, 'deg': 178, 'gust': 7.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-03 03:00:00'},
#   {'dt': 1667455200,
#    'main': {'temp': 8.27,
#     'feels_like': 5.99,
#     'temp_min': 8.27,
#     'temp_max': 8.27,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.77, 'deg': 180, 'gust': 10.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-03 06:00:00'},
#   {'dt': 1667466000,
#    'main': {'temp': 10.53,
#     'feels_like': 9.15,
#     'temp_min': 10.53,
#     'temp_max': 10.53,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.97, 'deg': 174, 'gust': 8.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-03 09:00:00'},
#   {'dt': 1667476800,
#    'main': {'temp': 13.3,
#     'feels_like': 11.89,
#     'temp_min': 13.3,
#     'temp_max': 13.3,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4, 'deg': 169, 'gust': 6.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-03 12:00:00'},
#   {'dt': 1667487600,
#    'main': {'temp': 12.41,
#     'feels_like': 11.09,
#     'temp_min': 12.41,
#     'temp_max': 12.41,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1007,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.37, 'deg': 136, 'gust': 7.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-03 15:00:00'},
#   {'dt': 1667498400,
#    'main': {'temp': 11.04,
#     'feels_like': 9.79,
#     'temp_min': 11.04,
#     'temp_max': 11.04,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1005,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.82, 'deg': 132, 'gust': 10.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-03 18:00:00'},
#   {'dt': 1667509200,
#    'main': {'temp': 10.46,
#     'feels_like': 9.23,
#     'temp_min': 10.46,
#     'temp_max': 10.46,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1003,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.79, 'deg': 125, 'gust': 10.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-03 21:00:00'},
#   {'dt': 1667520000,
#    'main': {'temp': 10.19,
#     'feels_like': 8.99,
#     'temp_min': 10.19,
#     'temp_max': 10.19,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.39, 'deg': 125, 'gust': 9.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-04 00:00:00'},
#   {'dt': 1667530800,
#    'main': {'temp': 9.52,
#     'feels_like': 7.61,
#     'temp_min': 9.52,
#     'temp_max': 9.52,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1000,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.59, 'deg': 110, 'gust': 9.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-04 03:00:00'},
#   {'dt': 1667541600,
#    'main': {'temp': 8.57,
#     'feels_like': 6.75,
#     'temp_min': 8.57,
#     'temp_max': 8.57,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 999,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 3.07, 'deg': 109, 'gust': 8.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-04 06:00:00'},
#   {'dt': 1667552400,
#    'main': {'temp': 11.28,
#     'feels_like': 10.27,
#     'temp_min': 11.28,
#     'temp_max': 11.28,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 999,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 3.37, 'deg': 109, 'gust': 5.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-04 09:00:00'},
#   {'dt': 1667563200,
#    'main': {'temp': 12.71,
#     'feels_like': 11.68,
#     'temp_min': 12.71,
#     'temp_max': 12.71,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 998,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 3.61, 'deg': 93, 'gust': 5.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-04 12:00:00'},
#   {'dt': 1667574000,
#    'main': {'temp': 11.47,
#     'feels_like': 10.4,
#     'temp_min': 11.47,
#     'temp_max': 11.47,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 998,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.06, 'deg': 93, 'gust': 6.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-04 15:00:00'},
#   {'dt': 1667584800,
#    'main': {'temp': 11.11,
#     'feels_like': 10.1,
#     'temp_min': 11.11,
#     'temp_max': 11.11,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 998,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.15, 'deg': 118, 'gust': 5.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-04 18:00:00'},
#   {'dt': 1667595600,
#    'main': {'temp': 10.51,
#     'feels_like': 9.6,
#     'temp_min': 10.51,
#     'temp_max': 10.51,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 999,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.22, 'deg': 144, 'gust': 1.97},
#    'visibility': 10000,
#    'pop': 0.31,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-04 21:00:00'},
#   {'dt': 1667606400,
#    'main': {'temp': 10.01,
#     'feels_like': 9.42,
#     'temp_min': 10.01,
#     'temp_max': 10.01,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1000,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.1, 'deg': 191, 'gust': 1.81},
#    'visibility': 10000,
#    'pop': 0.94,
#    'rain': {'3h': 1.55},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-05 00:00:00'},
#   {'dt': 1667617200,
#    'main': {'temp': 10.16,
#     'feels_like': 9.61,
#     'temp_min': 10.16,
#     'temp_max': 10.16,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1001,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.99, 'deg': 214, 'gust': 5.54},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-05 03:00:00'},
#   {'dt': 1667628000,
#    'main': {'temp': 9.87,
#     'feels_like': 7.99,
#     'temp_min': 9.87,
#     'temp_max': 9.87,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1002,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.69, 'deg': 205, 'gust': 7.45},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-05 06:00:00'},
#   {'dt': 1667638800,
#    'main': {'temp': 9.92,
#     'feels_like': 7.87,
#     'temp_min': 9.92,
#     'temp_max': 9.92,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.07, 'deg': 203, 'gust': 7.7},
#    'visibility': 10000,
#    'pop': 0.31,
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-05 09:00:00'},
#   {'dt': 1667649600,
#    'main': {'temp': 10.13,
#     'feels_like': 9.47,
#     'temp_min': 10.13,
#     'temp_max': 10.13,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.75, 'deg': 210, 'gust': 7.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-05 12:00:00'},
#   {'dt': 1667660400,
#    'main': {'temp': 10.19,
#     'feels_like': 9.61,
#     'temp_min': 10.19,
#     'temp_max': 10.19,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.34, 'deg': 210, 'gust': 7.45},
#    'visibility': 10000,
#    'pop': 0.25,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-05 15:00:00'},
#   {'dt': 1667671200,
#    'main': {'temp': 10.24,
#     'feels_like': 9.75,
#     'temp_min': 10.24,
#     'temp_max': 10.24,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.97, 'deg': 248, 'gust': 6.94},
#    'visibility': 10000,
#    'pop': 0.69,
#    'rain': {'3h': 0.64},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-05 18:00:00'},
#   {'dt': 1667682000,
#    'main': {'temp': 10.57,
#     'feels_like': 10.03,
#     'temp_min': 10.57,
#     'temp_max': 10.57,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.63, 'deg': 269, 'gust': 8.23},
#    'visibility': 10000,
#    'pop': 0.78,
#    'rain': {'3h': 0.38},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-05 21:00:00'},
#   {'dt': 1667692800,
#    'main': {'temp': 10.33,
#     'feels_like': 9.74,
#     'temp_min': 10.33,
#     'temp_max': 10.33,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.65, 'deg': 278, 'gust': 8.76},
#    'visibility': 10000,
#    'pop': 0.39,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-06 00:00:00'},
#   {'dt': 1667703600,
#    'main': {'temp': 7.75,
#     'feels_like': 5.82,
#     'temp_min': 7.75,
#     'temp_max': 7.75,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1013,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 2.99, 'deg': 271, 'gust': 7.66},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-06 03:00:00'},
#   {'dt': 1667714400,
#    'main': {'temp': 6.48,
#     'feels_like': 5.02,
#     'temp_min': 6.48,
#     'temp_max': 6.48,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 2.08, 'deg': 252, 'gust': 4.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-06 06:00:00'},
#   {'dt': 1667725200,
#    'main': {'temp': 8.59,
#     'feels_like': 7.27,
#     'temp_min': 8.59,
#     'temp_max': 8.59,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1014,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.34, 'deg': 224, 'gust': 4.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-06 09:00:00'},
#   {'dt': 1667736000,
#    'main': {'temp': 11.35,
#     'feels_like': 10.19,
#     'temp_min': 11.35,
#     'temp_max': 11.35,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.26, 'deg': 198, 'gust': 5.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-06 12:00:00'},
#   {'dt': 1667746800,
#    'main': {'temp': 10.58,
#     'feels_like': 9.44,
#     'temp_min': 10.58,
#     'temp_max': 10.58,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 46},
#    'wind': {'speed': 2.56, 'deg': 187, 'gust': 5.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-06 15:00:00'},
#   {'dt': 1667757600,
#    'main': {'temp': 9.16,
#     'feels_like': 7.52,
#     'temp_min': 9.16,
#     'temp_max': 9.16,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 2.97, 'deg': 184, 'gust': 8.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-06 18:00:00'},
#   {'dt': 1667768400,
#    'main': {'temp': 9.5,
#     'feels_like': 7.94,
#     'temp_min': 9.5,
#     'temp_max': 9.5,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.95, 'deg': 223, 'gust': 8.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-06 21:00:00'},
#   {'dt': 1667779200,
#    'main': {'temp': 9.38,
#     'feels_like': 7.48,
#     'temp_min': 9.38,
#     'temp_max': 9.38,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.52, 'deg': 210, 'gust': 9.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-07 00:00:00'},
#   {'dt': 1667790000,
#    'main': {'temp': 9.54,
#     'feels_like': 7.88,
#     'temp_min': 9.54,
#     'temp_max': 9.54,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.14, 'deg': 219, 'gust': 7.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-07 03:00:00'},
#   {'dt': 1667800800,
#    'main': {'temp': 8.82,
#     'feels_like': 7.06,
#     'temp_min': 8.82,
#     'temp_max': 8.82,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.06, 'deg': 218, 'gust': 7.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-07 06:00:00'},
#   {'dt': 1667811600,
#    'main': {'temp': 10.74,
#     'feels_like': 9.65,
#     'temp_min': 10.74,
#     'temp_max': 10.74,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 3.61, 'deg': 215, 'gust': 6.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-07 09:00:00'},
#   {'dt': 1667822400,
#    'main': {'temp': 13.26,
#     'feels_like': 12.23,
#     'temp_min': 13.26,
#     'temp_max': 13.26,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1014,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.35, 'deg': 222, 'gust': 5.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-07 12:00:00'},
#   {'dt': 1667833200,
#    'main': {'temp': 12.16,
#     'feels_like': 11.21,
#     'temp_min': 12.16,
#     'temp_max': 12.16,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.64, 'deg': 201, 'gust': 5.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-07 15:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 3600,
#   'sunrise': 1667369042,
#   'sunset': 1667403343}}

# %% [markdown]
# Now we've discovered what information we have to work with. Let's decide what we want to keep and what we wish to lose.
#
# I feel that from json['list'] it would be good to keep
# - 'weather.main', 'weather.description', 'dt_txt', 'main.temp', 'main.feels_like' 'clouds.all', 'rain.3h', 'snow.3h' 'wind.speed', 'wind.deg', 'main.humidity', 'main.pressure'.
#
# And from json['city'] it would be good to keep
# - 'name' and 'country.
#
# Just to make sure that we got the right place. And as an added extra we'll also include the time that API call was made, so we know how up to date our forecast is.

# %% [markdown]
# **Optional:** let's get a timestamp of when we get the data. Datetime uses the uses the current time of the system, which on local computers is normally correct. But as we're in the cloud, computers are not always in our country, and we therefore add on the timezone module to ensure that our timestamp is local to us and not the computer.

# %%
tz = pytz.timezone('Europe/Berlin')
now = datetime.now().astimezone(tz)

now
# Out:
# datetime.datetime(2022, 11, 2, 16, 1, 38, 118115, tzinfo=<DstTzInfo 'Europe/Berlin' CET+1:00:00 STD>)

# %%
json['list']
# Out:
# [{'dt': 1667412000,
#   'main': {'temp': 13.5,
#    'feels_like': 12.45,
#    'temp_min': 11.82,
#    'temp_max': 13.5,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1015,
#    'humidity': 59,
#    'temp_kf': 1.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.86, 'deg': 254, 'gust': 9.52},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-02 18:00:00'},
#  {'dt': 1667422800,
#   'main': {'temp': 11.52,
#    'feels_like': 10.42,
#    'temp_min': 10.11,
#    'temp_max': 11.52,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1016,
#    'humidity': 65,
#    'temp_kf': 1.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.12, 'deg': 242, 'gust': 8.76},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-02 21:00:00'},
#  {'dt': 1667433600,
#   'main': {'temp': 9.34,
#    'feels_like': 8.21,
#    'temp_min': 9.34,
#    'temp_max': 9.34,
#    'pressure': 1021,
#    'sea_level': 1021,
#    'grnd_level': 1016,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 48},
#   'wind': {'speed': 2.27, 'deg': 188, 'gust': 4.8},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-03 00:00:00'},
#  {'dt': 1667444400,
#   'main': {'temp': 8.61,
#    'feels_like': 6.77,
#    'temp_min': 8.61,
#    'temp_max': 8.61,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1015,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 3.12, 'deg': 178, 'gust': 7.87},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-03 03:00:00'},
#  {'dt': 1667455200,
#   'main': {'temp': 8.27,
#    'feels_like': 5.99,
#    'temp_min': 8.27,
#    'temp_max': 8.27,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1014,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 3.77, 'deg': 180, 'gust': 10.79},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-03 06:00:00'},
#  {'dt': 1667466000,
#   'main': {'temp': 10.53,
#    'feels_like': 9.15,
#    'temp_min': 10.53,
#    'temp_max': 10.53,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1012,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.97, 'deg': 174, 'gust': 8.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-03 09:00:00'},
#  {'dt': 1667476800,
#   'main': {'temp': 13.3,
#    'feels_like': 11.89,
#    'temp_min': 13.3,
#    'temp_max': 13.3,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4, 'deg': 169, 'gust': 6.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-03 12:00:00'},
#  {'dt': 1667487600,
#   'main': {'temp': 12.41,
#    'feels_like': 11.09,
#    'temp_min': 12.41,
#    'temp_max': 12.41,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 53,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.37, 'deg': 136, 'gust': 7.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-03 15:00:00'},
#  {'dt': 1667498400,
#   'main': {'temp': 11.04,
#    'feels_like': 9.79,
#    'temp_min': 11.04,
#    'temp_max': 11.04,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1005,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.82, 'deg': 132, 'gust': 10.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-03 18:00:00'},
#  {'dt': 1667509200,
#   'main': {'temp': 10.46,
#    'feels_like': 9.23,
#    'temp_min': 10.46,
#    'temp_max': 10.46,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.79, 'deg': 125, 'gust': 10.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-03 21:00:00'},
#  {'dt': 1667520000,
#   'main': {'temp': 10.19,
#    'feels_like': 8.99,
#    'temp_min': 10.19,
#    'temp_max': 10.19,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1002,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.39, 'deg': 125, 'gust': 9.24},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-04 00:00:00'},
#  {'dt': 1667530800,
#   'main': {'temp': 9.52,
#    'feels_like': 7.61,
#    'temp_min': 9.52,
#    'temp_max': 9.52,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 1000,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.59, 'deg': 110, 'gust': 9.53},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-04 03:00:00'},
#  {'dt': 1667541600,
#   'main': {'temp': 8.57,
#    'feels_like': 6.75,
#    'temp_min': 8.57,
#    'temp_max': 8.57,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 999,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 79},
#   'wind': {'speed': 3.07, 'deg': 109, 'gust': 8.23},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-04 06:00:00'},
#  {'dt': 1667552400,
#   'main': {'temp': 11.28,
#    'feels_like': 10.27,
#    'temp_min': 11.28,
#    'temp_max': 11.28,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 999,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 71},
#   'wind': {'speed': 3.37, 'deg': 109, 'gust': 5.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-04 09:00:00'},
#  {'dt': 1667563200,
#   'main': {'temp': 12.71,
#    'feels_like': 11.68,
#    'temp_min': 12.71,
#    'temp_max': 12.71,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 998,
#    'humidity': 63,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 3.61, 'deg': 93, 'gust': 5.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-04 12:00:00'},
#  {'dt': 1667574000,
#   'main': {'temp': 11.47,
#    'feels_like': 10.4,
#    'temp_min': 11.47,
#    'temp_max': 11.47,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 998,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.06, 'deg': 93, 'gust': 6.12},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-04 15:00:00'},
#  {'dt': 1667584800,
#   'main': {'temp': 11.11,
#    'feels_like': 10.1,
#    'temp_min': 11.11,
#    'temp_max': 11.11,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 998,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.15, 'deg': 118, 'gust': 5.07},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-04 18:00:00'},
#  {'dt': 1667595600,
#   'main': {'temp': 10.51,
#    'feels_like': 9.6,
#    'temp_min': 10.51,
#    'temp_max': 10.51,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 999,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.22, 'deg': 144, 'gust': 1.97},
#   'visibility': 10000,
#   'pop': 0.31,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-04 21:00:00'},
#  {'dt': 1667606400,
#   'main': {'temp': 10.01,
#    'feels_like': 9.42,
#    'temp_min': 10.01,
#    'temp_max': 10.01,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 1000,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.1, 'deg': 191, 'gust': 1.81},
#   'visibility': 10000,
#   'pop': 0.94,
#   'rain': {'3h': 1.55},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-05 00:00:00'},
#  {'dt': 1667617200,
#   'main': {'temp': 10.16,
#    'feels_like': 9.61,
#    'temp_min': 10.16,
#    'temp_max': 10.16,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 1001,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.99, 'deg': 214, 'gust': 5.54},
#   'visibility': 10000,
#   'pop': 0.49,
#   'rain': {'3h': 0.26},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-05 03:00:00'},
#  {'dt': 1667628000,
#   'main': {'temp': 9.87,
#    'feels_like': 7.99,
#    'temp_min': 9.87,
#    'temp_max': 9.87,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.69, 'deg': 205, 'gust': 7.45},
#   'visibility': 10000,
#   'pop': 0.29,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-05 06:00:00'},
#  {'dt': 1667638800,
#   'main': {'temp': 9.92,
#    'feels_like': 7.87,
#    'temp_min': 9.92,
#    'temp_max': 9.92,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1005,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.07, 'deg': 203, 'gust': 7.7},
#   'visibility': 10000,
#   'pop': 0.31,
#   'rain': {'3h': 0.18},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-05 09:00:00'},
#  {'dt': 1667649600,
#   'main': {'temp': 10.13,
#    'feels_like': 9.47,
#    'temp_min': 10.13,
#    'temp_max': 10.13,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1006,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.75, 'deg': 210, 'gust': 7.65},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-05 12:00:00'},
#  {'dt': 1667660400,
#   'main': {'temp': 10.19,
#    'feels_like': 9.61,
#    'temp_min': 10.19,
#    'temp_max': 10.19,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.34, 'deg': 210, 'gust': 7.45},
#   'visibility': 10000,
#   'pop': 0.25,
#   'rain': {'3h': 0.17},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-05 15:00:00'},
#  {'dt': 1667671200,
#   'main': {'temp': 10.24,
#    'feels_like': 9.75,
#    'temp_min': 10.24,
#    'temp_max': 10.24,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 93,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.97, 'deg': 248, 'gust': 6.94},
#   'visibility': 10000,
#   'pop': 0.69,
#   'rain': {'3h': 0.64},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-05 18:00:00'},
#  {'dt': 1667682000,
#   'main': {'temp': 10.57,
#    'feels_like': 10.03,
#    'temp_min': 10.57,
#    'temp_max': 10.57,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1011,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.63, 'deg': 269, 'gust': 8.23},
#   'visibility': 10000,
#   'pop': 0.78,
#   'rain': {'3h': 0.38},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-05 21:00:00'},
#  {'dt': 1667692800,
#   'main': {'temp': 10.33,
#    'feels_like': 9.74,
#    'temp_min': 10.33,
#    'temp_max': 10.33,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.65, 'deg': 278, 'gust': 8.76},
#   'visibility': 10000,
#   'pop': 0.39,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-06 00:00:00'},
#  {'dt': 1667703600,
#   'main': {'temp': 7.75,
#    'feels_like': 5.82,
#    'temp_min': 7.75,
#    'temp_max': 7.75,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1013,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 2.99, 'deg': 271, 'gust': 7.66},
#   'visibility': 10000,
#   'pop': 0.01,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-06 03:00:00'},
#  {'dt': 1667714400,
#   'main': {'temp': 6.48,
#    'feels_like': 5.02,
#    'temp_min': 6.48,
#    'temp_max': 6.48,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1014,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 2.08, 'deg': 252, 'gust': 4.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-06 06:00:00'},
#  {'dt': 1667725200,
#   'main': {'temp': 8.59,
#    'feels_like': 7.27,
#    'temp_min': 8.59,
#    'temp_max': 8.59,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1014,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.34, 'deg': 224, 'gust': 4.04},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-06 09:00:00'},
#  {'dt': 1667736000,
#   'main': {'temp': 11.35,
#    'feels_like': 10.19,
#    'temp_min': 11.35,
#    'temp_max': 11.35,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 63,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 3.26, 'deg': 198, 'gust': 5.03},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-06 12:00:00'},
#  {'dt': 1667746800,
#   'main': {'temp': 10.58,
#    'feels_like': 9.44,
#    'temp_min': 10.58,
#    'temp_max': 10.58,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1012,
#    'humidity': 67,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 46},
#   'wind': {'speed': 2.56, 'deg': 187, 'gust': 5.58},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-06 15:00:00'},
#  {'dt': 1667757600,
#   'main': {'temp': 9.16,
#    'feels_like': 7.52,
#    'temp_min': 9.16,
#    'temp_max': 9.16,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 71},
#   'wind': {'speed': 2.97, 'deg': 184, 'gust': 8.3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-06 18:00:00'},
#  {'dt': 1667768400,
#   'main': {'temp': 9.5,
#    'feels_like': 7.94,
#    'temp_min': 9.5,
#    'temp_max': 9.5,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.95, 'deg': 223, 'gust': 8.62},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-06 21:00:00'},
#  {'dt': 1667779200,
#   'main': {'temp': 9.38,
#    'feels_like': 7.48,
#    'temp_min': 9.38,
#    'temp_max': 9.38,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.52, 'deg': 210, 'gust': 9.8},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-07 00:00:00'},
#  {'dt': 1667790000,
#   'main': {'temp': 9.54,
#    'feels_like': 7.88,
#    'temp_min': 9.54,
#    'temp_max': 9.54,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1013,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.14, 'deg': 219, 'gust': 7.9},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-07 03:00:00'},
#  {'dt': 1667800800,
#   'main': {'temp': 8.82,
#    'feels_like': 7.06,
#    'temp_min': 8.82,
#    'temp_max': 8.82,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1014,
#    'humidity': 76,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 3.06, 'deg': 218, 'gust': 7.32},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2022-11-07 06:00:00'},
#  {'dt': 1667811600,
#   'main': {'temp': 10.74,
#    'feels_like': 9.65,
#    'temp_min': 10.74,
#    'temp_max': 10.74,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1015,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 89},
#   'wind': {'speed': 3.61, 'deg': 215, 'gust': 6.43},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-07 09:00:00'},
#  {'dt': 1667822400,
#   'main': {'temp': 13.26,
#    'feels_like': 12.23,
#    'temp_min': 13.26,
#    'temp_max': 13.26,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1014,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 3.35, 'deg': 222, 'gust': 5.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-07 12:00:00'},
#  {'dt': 1667833200,
#   'main': {'temp': 12.16,
#    'feels_like': 11.21,
#    'temp_min': 12.16,
#    'temp_max': 12.16,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1014,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.64, 'deg': 201, 'gust': 5.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-07 15:00:00'}]

# %% [markdown]
# **Next** let's loop through the json['list'] information get the weather information

# %%
# we'll store the information in this dicitonary:
weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': [],
                'information_retrieved_at': []}

# let's begin the loop
for i in json['list']:
  weather_dict['city'].append(json['city']['name'])
  weather_dict['country'].append(json['city']['country'])
  weather_dict['forecast_time'].append(i['dt_txt'])
  weather_dict['outlook'].append(i['weather'][0]['main'])
  weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
  weather_dict['temperature'].append(i['main']['temp'])
  weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
  weather_dict['clouds'].append(i['clouds']['all'])
  # sometimes the data is missing for rain and snow. As it is not always raining or snowing
  # we cannot make a DataFrame unless the lists are all the same length, therefore missing values are bad
  # here we say try to append a value if there is one. If not, append a 0
  try:
      weather_dict['rain'].append(i['rain']['3h'])
  except:
      weather_dict['rain'].append('0')
  try:
      weather_dict['snow'].append(i['snow']['3h'])
  except:
      weather_dict['snow'].append('0')
  weather_dict['wind_speed'].append(i['wind']['speed'])
  weather_dict['wind_deg'].append(i['wind']['deg'])
  weather_dict['humidity'].append(i['main']['humidity'])
  weather_dict['pressure'].append(i['main']['pressure'])
  weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

# %% [markdown]
# **Now** we convert our dictionary to a DataFrame

# %%
weather_from_dict_df = pd.DataFrame(weather_dict)

weather_from_dict_df.head()
# Out:
#      city country        forecast_time outlook detailed_outlook  temperature  \
# 0  Berlin      DE  2022-11-02 12:00:00  Clouds       few clouds        13.79
# 1  Berlin      DE  2022-11-02 15:00:00  Clouds       few clouds        13.44
# 2  Berlin      DE  2022-11-02 18:00:00   Clear        clear sky        11.46
# 3  Berlin      DE  2022-11-02 21:00:00   Clear        clear sky         9.89
# 4  Berlin      DE  2022-11-03 00:00:00  Clouds       few clouds         8.87
#
#    temperature_feels_like  clouds rain snow  wind_speed  wind_deg  humidity  \
# 0                   13.00      23    0    0        6.20       251        68
# 1                   12.43      13    0    0        5.62       256        61
# 2                   10.25       7    0    0        3.68       252        61
# 3                    8.58       2    0    0        2.67       233        67
# 4                    7.66      11    0    0        2.26       186        71
#
#    pressure information_retrieved_at
# 0      1012      02/11/2022 10:41:53
# 1      1016      02/11/2022 10:41:53
# 2      1021      02/11/2022 10:41:53
# 3      1022      02/11/2022 10:41:53
# 4      1021      02/11/2022 10:41:53

# %% [markdown]
# **As a final step**, to keep everything tidy: let's bring everything we did together in a function. And allow the function to take a list of cities as an input

# %%
def get_weather_loop(cities):

  API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'

  tz = pytz.timezone('Europe/Berlin')
  now = datetime.now().astimezone(tz)

  weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': [],
                'information_retrieved_at': []}

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
    response = requests.get(url)
    json = response.json()

    for i in json['list']:
      weather_dict['city'].append(json['city']['name'])
      weather_dict['country'].append(json['city']['country'])
      weather_dict['forecast_time'].append(i['dt_txt'])
      weather_dict['outlook'].append(i['weather'][0]['main'])
      weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
      weather_dict['temperature'].append(i['main']['temp'])
      weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
      weather_dict['clouds'].append(i['clouds']['all'])
      try:
          weather_dict['rain'].append(i['rain']['3h'])
      except:
          weather_dict['rain'].append('0')
      try:
          weather_dict['snow'].append(i['snow']['3h'])
      except:
          weather_dict['snow'].append('0')
      weather_dict['wind_speed'].append(i['wind']['speed'])
      weather_dict['wind_deg'].append(i['wind']['deg'])
      weather_dict['humidity'].append(i['main']['humidity'])
      weather_dict['pressure'].append(i['main']['pressure'])
      weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

  return pd.DataFrame(weather_dict)

# %%
get_weather_loop(['Berlin', 'London'])
# Out:
#       city country        forecast_time outlook detailed_outlook  temperature  \
# 0   Berlin      DE  2022-11-02 12:00:00   Clear        clear sky        15.07
# 1   Berlin      DE  2022-11-02 15:00:00   Clear        clear sky        14.61
# 2   Berlin      DE  2022-11-02 18:00:00   Clear        clear sky        12.66
# 3   Berlin      DE  2022-11-02 21:00:00   Clear        clear sky         9.89
# 4   Berlin      DE  2022-11-03 00:00:00  Clouds       few clouds         8.87
# ..     ...     ...                  ...     ...              ...          ...
# 75  London      GB  2022-11-06 21:00:00  Clouds  overcast clouds        12.33
# 76  London      GB  2022-11-07 00:00:00  Clouds  overcast clouds        12.65
# 77  London      GB  2022-11-07 03:00:00  Clouds  overcast clouds        13.10
# 78  London      GB  2022-11-07 06:00:00    Rain       light rain        13.54
# 79  London      GB  2022-11-07 09:00:00  Clouds  overcast clouds        14.03
#
#     temperature_feels_like  clouds  rain snow  wind_speed  wind_deg  humidity  \
# 0                    14.33       0     0    0        6.20       251        65
# 1                    13.72       3     0    0        5.62       256        61
# 2                    11.60       5     0    0        3.68       252        62
# 3                     8.58       2     0    0        2.67       233        67
# 4                     7.66      11     0    0        2.26       186        71
# ..                     ...     ...   ...  ...         ...       ...       ...
# 75                   11.60     100     0    0        5.30       217        76
# 76                   12.03     100     0    0        5.57       214        79
# 77                   12.61     100     0    0        6.40       208        82
# 78                   13.06     100  0.13    0        6.82       210        81
# 79                   13.53     100     0    0        6.41       210        78
#
#     pressure information_retrieved_at
# 0       1009      02/11/2022 11:55:50
# 1       1013      02/11/2022 11:55:50
# 2       1017      02/11/2022 11:55:50
# 3       1022      02/11/2022 11:55:50
# 4       1021      02/11/2022 11:55:50
# ..       ...                      ...
# 75      1009      02/11/2022 11:55:50
# 76      1009      02/11/2022 11:55:50
# 77      1008      02/11/2022 11:55:50
# 78      1008      02/11/2022 11:55:50
# 79      1009      02/11/2022 11:55:50
#
# [80 rows x 15 columns]

# %% [markdown]
# # Solution using `.json_normalize()`

# %% [markdown]
# **First** we need to make an API call to get our information

# %%
city = 'Berlin'
API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric") 
response = requests.get(url)
json = response.json()

# %% [markdown]
# If we now try to use `.json_normalize()` on the `list` part of the json, you'll see that json_normalize can get confused when it hits a list instead of a subdictionary. Take a look at the weather column below

# %%
#pd.json_normalize(resp["list"]["weather"])
#pd.json_normalize(wea_resp, record_path= ["list", "weather"], errors="ignore")

# %%
pd.DataFrame((json['list'])).head()
# Out:
#            dt                                               main  \
# 0  1667390400  {'temp': 13.79, 'feels_like': 13, 'temp_min': ...
# 1  1667401200  {'temp': 13.44, 'feels_like': 12.43, 'temp_min...
# 2  1667412000  {'temp': 11.46, 'feels_like': 10.25, 'temp_min...
# 3  1667422800  {'temp': 9.89, 'feels_like': 8.58, 'temp_min':...
# 4  1667433600  {'temp': 8.87, 'feels_like': 7.66, 'temp_min':...
#
#                                              weather       clouds  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 23}
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 13}
# 2  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 7}
# 3  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 2}
# 4  [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 11}
#
#                                          wind  visibility  pop           sys  \
# 0   {'speed': 6.2, 'deg': 251, 'gust': 10.75}       10000  0.0  {'pod': 'd'}
# 1  {'speed': 5.62, 'deg': 256, 'gust': 11.28}       10000  0.0  {'pod': 'd'}
# 2   {'speed': 3.68, 'deg': 252, 'gust': 9.36}       10000  0.0  {'pod': 'n'}
# 3   {'speed': 2.67, 'deg': 233, 'gust': 7.17}       10000  0.0  {'pod': 'n'}
# 4   {'speed': 2.26, 'deg': 186, 'gust': 4.33}       10000  0.0  {'pod': 'n'}
#
#                 dt_txt rain
# 0  2022-11-02 12:00:00  NaN
# 1  2022-11-02 15:00:00  NaN
# 2  2022-11-02 18:00:00  NaN
# 3  2022-11-02 21:00:00  NaN
# 4  2022-11-03 00:00:00  NaN

# %% [markdown]
# To fix this we need to flatten the nested list using the parameter `record_path`, and then select the other columns we'd like using the parameter `meta`. At the end of the json_normalize parameters we have `errors='ignore'`, which means that if ever there is a missing value in the JSON, a `NaN` gets inserted into the table. If you'd like more information, please check out the [docs](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html)

# %%
json_norm_df = pd.json_normalize(json['list'], 
                                record_path=['weather'], 
                                meta=['dt_txt', ['main', 'temp'], ['main', 'feels_like'], ['clouds', 'all'], ['rain', '3h'], ['snow', '3h'], ['wind', 'speed'], ['wind', 'deg'], ['main', 'humidity'], ['main', 'pressure']],
                                errors='ignore')

json_norm_df.head()
# Out:
#     id    main description icon               dt_txt main.temp  \
# 0  801  Clouds  few clouds  02d  2022-11-02 12:00:00     13.79
# 1  801  Clouds  few clouds  02d  2022-11-02 15:00:00     13.44
# 2  800   Clear   clear sky  01n  2022-11-02 18:00:00     11.46
# 3  800   Clear   clear sky  01n  2022-11-02 21:00:00      9.89
# 4  801  Clouds  few clouds  02n  2022-11-03 00:00:00      8.87
#
#   main.feels_like clouds.all rain.3h snow.3h wind.speed wind.deg  \
# 0              13         23     NaN     NaN        6.2      251
# 1           12.43         13     NaN     NaN       5.62      256
# 2           10.25          7     NaN     NaN       3.68      252
# 3            8.58          2     NaN     NaN       2.67      233
# 4            7.66         11     NaN     NaN       2.26      186
#
#   main.humidity main.pressure
# 0            68          1012
# 1            61          1016
# 2            61          1021
# 3            67          1022
# 4            71          1021

# %% [markdown]
# Now let's tidy this DataFrame up by
# - dropping some columns
# - renaming some columns
# - adding some columns

# %%
# drop id and icon
json_norm_df = json_norm_df.drop(columns=['id', 'icon']).copy()

# %%
# rename some columns
json_norm_df.rename(columns={'main': 'outlook',
                             'description': 'detailed_outlook',
                             'dt_txt': 'forecast_time',
                             'main.temp': 'temperature',
                             'main.feels_like': 'temperature_feels_like',
                             'clouds.all': 'clouds',
                             'rain.3h': 'rain',
                             'snow.3h': 'snow',
                             'wind.speed': 'wind_speed',
                             'wind.deg': 'wind_deg',
                             'main.humidity': 'humidity',
                             'main.pressure': 'pressure',},
                    inplace=True)

# %%
# add some columns
json_norm_df.insert(0, 'city', json['city']['name'])
json_norm_df.insert(1, 'country', json['city']['country'])
json_norm_df['information_retrieved_at'] = now.strftime("%d/%m/%Y %H:%M:%S")

# rearrange the columns
json_norm_df = json_norm_df[['city', 'country', 'forecast_time', 'outlook', 'detailed_outlook',
       'temperature', 'temperature_feels_like', 'clouds', 'rain', 'snow',
       'wind_speed', 'wind_deg', 'humidity', 'pressure',
       'information_retrieved_at']]

json_norm_df.head()
# Out:
#      city country        forecast_time outlook detailed_outlook temperature  \
# 0  Berlin      DE  2022-11-02 12:00:00  Clouds       few clouds       13.79
# 1  Berlin      DE  2022-11-02 15:00:00  Clouds       few clouds       13.44
# 2  Berlin      DE  2022-11-02 18:00:00   Clear        clear sky       11.46
# 3  Berlin      DE  2022-11-02 21:00:00   Clear        clear sky        9.89
# 4  Berlin      DE  2022-11-03 00:00:00  Clouds       few clouds        8.87
#
#   temperature_feels_like clouds rain snow wind_speed wind_deg humidity  \
# 0                     13     23  NaN  NaN        6.2      251       68
# 1                  12.43     13  NaN  NaN       5.62      256       61
# 2                  10.25      7  NaN  NaN       3.68      252       61
# 3                   8.58      2  NaN  NaN       2.67      233       67
# 4                   7.66     11  NaN  NaN       2.26      186       71
#
#   pressure information_retrieved_at
# 0     1012      02/11/2022 10:41:53
# 1     1016      02/11/2022 10:41:53
# 2     1021      02/11/2022 10:41:53
# 3     1022      02/11/2022 10:41:53
# 4     1021      02/11/2022 10:41:53

# %% [markdown]
# Now we have a very similar DataFrame to what we had with the for loop. Again, let's put this in a function that can take a list of cities

# %%
def get_weather_norm(cities):
  
  API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'

  df_list = []

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric") 
    response = requests.get(url)
    json = response.json()

    json_norm_df = pd.json_normalize(json['list'], 
                                record_path=['weather'], 
                                meta=['dt_txt', ['main', 'temp'], ['main', 'feels_like'], ['clouds', 'all'], ['rain', '3h'], ['snow', '3h'], ['wind', 'speed'], ['wind', 'deg'], ['main', 'humidity'], ['main', 'pressure']], 
                                errors='ignore')
    json_norm_df.drop(columns=['id', 'icon'], inplace=True)
    json_norm_df.rename(columns={'main': 'outlook',
                             'description': 'detailed_outlook',
                             'dt_txt': 'forecast_time',
                             'main.temp': 'temperature',
                             'main.feels_like': 'temperature_feels_like',
                             'clouds.all': 'clouds',
                             'rain.3h': 'rain',
                             'snow.3h': 'snow',
                             'wind.speed': 'wind_speed',
                             'wind.deg': 'wind_deg',
                             'main.humidity': 'humidity',
                             'main.pressure': 'pressure',},
                    inplace=True)
    json_norm_df.insert(0, 'city', json['city']['name'])
    json_norm_df.insert(1, 'country', json['city']['country'])
    json_norm_df['information_retrieved_at'] = now.strftime("%d/%m/%Y %H:%M:%S")
    json_norm_df[['city', 'country', 'forecast_time', 'outlook', 'detailed_outlook',
          'temperature', 'temperature_feels_like', 'clouds', 'rain', 'snow',
          'wind_speed', 'wind_deg', 'humidity', 'pressure',
          'information_retrieved_at']]
    df_list.append(json_norm_df)
  return pd.concat(df_list, ignore_index=True)

# %%
get_weather_norm(['Berlin', 'London'])
# Out:
#       city country outlook detailed_outlook        forecast_time temperature  \
# 0   Berlin      DE  Clouds       few clouds  2022-11-02 12:00:00       13.79
# 1   Berlin      DE  Clouds       few clouds  2022-11-02 15:00:00       13.44
# 2   Berlin      DE   Clear        clear sky  2022-11-02 18:00:00       11.46
# 3   Berlin      DE   Clear        clear sky  2022-11-02 21:00:00        9.89
# 4   Berlin      DE  Clouds       few clouds  2022-11-03 00:00:00        8.87
# ..     ...     ...     ...              ...                  ...         ...
# 75  London      GB  Clouds  overcast clouds  2022-11-06 21:00:00       12.33
# 76  London      GB  Clouds  overcast clouds  2022-11-07 00:00:00       12.65
# 77  London      GB  Clouds  overcast clouds  2022-11-07 03:00:00        13.1
# 78  London      GB    Rain       light rain  2022-11-07 06:00:00       13.54
# 79  London      GB  Clouds  overcast clouds  2022-11-07 09:00:00       14.03
#
#    temperature_feels_like clouds  rain snow wind_speed wind_deg humidity  \
# 0                      13     23   NaN  NaN        6.2      251       68
# 1                   12.43     13   NaN  NaN       5.62      256       61
# 2                   10.25      7   NaN  NaN       3.68      252       61
# 3                    8.58      2   NaN  NaN       2.67      233       67
# 4                    7.66     11   NaN  NaN       2.26      186       71
# ..                    ...    ...   ...  ...        ...      ...      ...
# 75                   11.6    100   NaN  NaN        5.3      217       76
# 76                  12.03    100   NaN  NaN       5.57      214       79
# 77                  12.61    100   NaN  NaN        6.4      208       82
# 78                  13.06    100  0.13  NaN       6.82      210       81
# 79                  13.53    100   NaN  NaN       6.41      210       78
#
#    pressure information_retrieved_at
# 0      1012      02/11/2022 10:41:53
# 1      1016      02/11/2022 10:41:53
# 2      1021      02/11/2022 10:41:53
# 3      1022      02/11/2022 10:41:53
# 4      1021      02/11/2022 10:41:53
# ..      ...                      ...
# 75     1009      02/11/2022 10:41:53
# 76     1009      02/11/2022 10:41:53
# 77     1008      02/11/2022 10:41:53
# 78     1008      02/11/2022 10:41:53
# 79     1009      02/11/2022 10:41:53
#
# [80 rows x 15 columns]
